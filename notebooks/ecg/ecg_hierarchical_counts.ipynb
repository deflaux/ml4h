# %%
import pandas as pd
from ml4cvd.arguments import _get_tmap
from ml4cvd.tensor_generators import get_test_train_valid_paths
from ml4cvd.tensor_maps_by_hand import TMAPS

train_paths, valid_paths, test_paths = get_test_train_valid_paths('/mnt/disks/ecg-rest-37k-tensors/2019-11-04/', 0.1, 0.1, 10, None)
all_paths = train_paths+valid_paths+test_paths
# Out:
# /usr/local/lib/python3.6/dist-packages/apache_beam/__init__.py:84: UserWarning: Running the Apache Beam SDK on Python 3 is not yet fully supported. You may encounter buggy behavior or missing features.
#   'Running the Apache Beam SDK on Python 3 is not yet fully supported. '
# Using TensorFlow backend.

# %%
import h5py
import numpy as np
import time
df_dic = {'full_path': [], 'patient_id': [], 'ecg_rest_text': [], 
          'rr': [], 'pp': [], 'pr': [], 'qrs': [],  'qt': [], 'qtc': [], 'paxis': [], 'raxis': [], 'taxis': []
         }
cnt = 0
for path in all_paths:
    hd5 = h5py.File(path, 'r')
    df_dic['full_path'].append(path)
    df_dic['patient_id'].append(path.split('/')[-1].split('.hd5')[0])
    time_start = time.time()
    df_dic['ecg_rest_text'].append(hd5['ecg_rest_text'][0])
    time_string = time.time()
    try:
        df_dic['rr'].append(hd5['continuous']['RRInterval'][0])    
    except:
        print(f"{df_dic['patient_id'][-1]} does not have RR measure tensorized")
        df_dic['rr'].append(np.nan)
    time_rr = time.time()
    try:
        df_dic['pp'].append(hd5['continuous']['PPInterval'][0])
    except:
        print(f"{df_dic['patient_id'][-1]} does not have PP measure tensorized")
        df_dic['pp'].append(np.nan)
    time_pp = time.time()
    try:
        df_dic['pr'].append(hd5['continuous']['PQInterval'][0])
        df_dic['paxis'].append(hd5['continuous']['PAxis'][0])
    except:
        print(f"{df_dic['patient_id'][-1]} does not have P measures tensorized")
        df_dic['pr'].append(np.nan)
        df_dic['paxis'].append(np.nan)
    time_pr = time.time()
    try:
        df_dic['qrs'].append(hd5['continuous']['QRSDuration'][0])
        df_dic['qt'].append(hd5['continuous']['QTInterval'][0])
        df_dic['qtc'].append(hd5['continuous']['QTCInterval'][0])
    except:
        print(f"{df_dic['patient_id'][-1]} does not have QRS measures tensorized")
        df_dic['qrs'].append(np.nan)
        df_dic['qt'].append(np.nan)
        df_dic['qtc'].append(np.nan)
    time_qt = time.time()
    try:
        df_dic['raxis'].append(hd5['continuous']['RAxis'][0])
        df_dic['taxis'].append(hd5['continuous']['TAxis'][0])
    except:
        print(f"{df_dic['patient_id'][-1]} does not have R and T axis measures tensorized")
        df_dic['raxis'].append(np.nan)
        df_dic['taxis'].append(np.nan)
    time_axis = time.time()
    hd5.close()
    cnt += 1
    #print(time_string-time_start, time_rr-time_start, time_pp-time_start, time_pr-time_start, time_qt-time_start, time_axis-time_start)
    #if cnt == 1000: break
# Out:
# 1375178 does not have P measures tensorized
# 2010028 does not have P measures tensorized
# 5876351 does not have P measures tensorized
# 2595478 does not have P measures tensorized
# 4704083 does not have P measures tensorized
# 1305569 does not have P measures tensorized
# 2451885 does not have P measures tensorized
# 1725073 does not have P measures tensorized
# 4638794 does not have P measures tensorized
# 5113555 does not have P measures tensorized
# 5437167 does not have P measures tensorized
# 2365842 does not have P measures tensorized
# 5578346 does not have P measures tensorized
# 2324937 does not have P measures tensorized
# 1282799 does not have P measures tensorized
# 5310597 does not have P measures tensorized
# 6008308 does not have P measures tensorized
# 3777821 does not have P measures tensorized
# 4396775 does not have P measures tensorized
# 1782079 does not have P measures tensorized
# 3800226 does not have P measures tensorized
# 1117558 does not have P measures tensorized
# 4560984 does not have P measures tensorized
# 3111789 does not have P measures tensorized
# 2493384 does not have P measures tensorized
# 2500937 does not have P measures tensorized
# 1658245 does not have P measures tensorized
# 5784443 does not have P measures tensorized
# 4563817 does not have P measures tensorized
# 1222972 does not have P measures tensorized
# 1821266 does not have P measures tensorized
# 5108305 does not have P measures tensorized
# 2507328 does not have P measures tensorized
# 4948937 does not have P measures tensorized
# 3724879 does not have P measures tensorized
# 2444342 does not have P measures tensorized
# 1070707 does not have P measures tensorized
# 2627578 does not have P measures tensorized
# 3388428 does not have P measures tensorized
# 4116524 does not have P measures tensorized
# 4348917 does not have P measures tensorized
# 4889425 does not have P measures tensorized
# 5226043 does not have P measures tensorized
# 5331386 does not have P measures tensorized
# 1034369 does not have P measures tensorized
# 2726592 does not have P measures tensorized
# 1916602 does not have P measures tensorized
# 5581882 does not have P measures tensorized
# 5945397 does not have P measures tensorized
# 4312204 does not have P measures tensorized
# 1423293 does not have P measures tensorized
# 3213618 does not have P measures tensorized
# 3321847 does not have P measures tensorized
# 2136529 does not have P measures tensorized
# 1648553 does not have P measures tensorized
# 1331575 does not have P measures tensorized
# 1798497 does not have P measures tensorized
# 5638384 does not have P measures tensorized
# 3360888 does not have P measures tensorized
# 3648548 does not have P measures tensorized
# 4233615 does not have P measures tensorized
# 5412653 does not have P measures tensorized
# 3000183 does not have P measures tensorized
# 5143513 does not have P measures tensorized
# 2644697 does not have P measures tensorized
# 5485056 does not have P measures tensorized
# 1301596 does not have P measures tensorized
# 1341712 does not have P measures tensorized
# 4603344 does not have P measures tensorized
# 3656995 does not have P measures tensorized
# 2198923 does not have P measures tensorized
# 1410223 does not have P measures tensorized
# 4295395 does not have P measures tensorized
# 2862611 does not have P measures tensorized
# 4671906 does not have P measures tensorized
# 2926988 does not have P measures tensorized
# 3091718 does not have P measures tensorized
# 3849082 does not have P measures tensorized
# 2595041 does not have P measures tensorized
# 5722099 does not have P measures tensorized
# 1645329 does not have P measures tensorized
# 4040037 does not have P measures tensorized
# 2964373 does not have P measures tensorized
# 2930731 does not have P measures tensorized
# 2657902 does not have P measures tensorized
# 3826965 does not have P measures tensorized
# 2932908 does not have P measures tensorized
# 2223467 does not have P measures tensorized
# 5691945 does not have P measures tensorized
# 2145753 does not have P measures tensorized
# 1600886 does not have P measures tensorized
# 2409921 does not have P measures tensorized
# 2716594 does not have P measures tensorized
# 4781396 does not have P measures tensorized
# 4235288 does not have P measures tensorized
# 5239213 does not have P measures tensorized
# 2986064 does not have P measures tensorized
# 1144296 does not have P measures tensorized
# 5107193 does not have P measures tensorized
# 2339215 does not have P measures tensorized
# 4530701 does not have P measures tensorized
# 4099442 does not have P measures tensorized
# 2655807 does not have P measures tensorized
# 1650554 does not have P measures tensorized
# 5943952 does not have P measures tensorized
# 3993644 does not have P measures tensorized
# 2850372 does not have P measures tensorized
# 3135195 does not have P measures tensorized
# 4016473 does not have P measures tensorized
# 4671953 does not have P measures tensorized
# 5811403 does not have P measures tensorized
# 2128177 does not have P measures tensorized
# 4678587 does not have P measures tensorized
# 2944453 does not have P measures tensorized
# 3372051 does not have P measures tensorized
# 2966385 does not have P measures tensorized
# 4593309 does not have P measures tensorized
# 1389924 does not have P measures tensorized
# 3014911 does not have P measures tensorized
# 3837931 does not have P measures tensorized
# 1437725 does not have P measures tensorized
# 2358569 does not have P measures tensorized
# 3137188 does not have P measures tensorized
# 5593484 does not have RR measure tensorized
# 5593484 does not have PP measure tensorized
# 5593484 does not have P measures tensorized
# 5593484 does not have QRS measures tensorized
# 5593484 does not have R and T axis measures tensorized
# 5301102 does not have P measures tensorized
# 3626753 does not have P measures tensorized
# 2910081 does not have P measures tensorized
# 1130073 does not have P measures tensorized
# 4886378 does not have P measures tensorized
# 2231197 does not have P measures tensorized
# 3150365 does not have P measures tensorized
# 3556403 does not have P measures tensorized
# 3796517 does not have P measures tensorized
# 5344596 does not have P measures tensorized
# 1318108 does not have P measures tensorized
# 2923221 does not have P measures tensorized
# 2423089 does not have P measures tensorized
# 2686637 does not have P measures tensorized
# 3756818 does not have P measures tensorized
# 4909551 does not have P measures tensorized
# 1120665 does not have P measures tensorized
# 1809808 does not have P measures tensorized
# 2761681 does not have P measures tensorized
# 2338937 does not have P measures tensorized
# 3285123 does not have P measures tensorized
# 3996171 does not have P measures tensorized
# 4625079 does not have P measures tensorized
# 1203789 does not have P measures tensorized
# 3925126 does not have P measures tensorized
# 4980448 does not have P measures tensorized
# 5024996 does not have P measures tensorized
# 2915619 does not have P measures tensorized
# 1286494 does not have P measures tensorized
# 1046641 does not have P measures tensorized
# 5167492 does not have P measures tensorized
# 1663441 does not have P measures tensorized
# 2687008 does not have P measures tensorized
# 3356278 does not have P measures tensorized
# 3438811 does not have P measures tensorized
# 5759165 does not have P measures tensorized
# 1262665 does not have P measures tensorized
# 1575194 does not have P measures tensorized
# 1810071 does not have P measures tensorized
# 1127376 does not have P measures tensorized
# 5788756 does not have P measures tensorized
# 3493044 does not have P measures tensorized
# 5560806 does not have P measures tensorized
# 3346518 does not have P measures tensorized
# 4597238 does not have P measures tensorized
# 5712187 does not have P measures tensorized
# 2295549 does not have P measures tensorized
# 2158065 does not have P measures tensorized
# 4806174 does not have P measures tensorized
# 2197065 does not have P measures tensorized
# 1100377 does not have P measures tensorized
# 5360014 does not have P measures tensorized
# 3571695 does not have P measures tensorized
# 5178259 does not have P measures tensorized
# 2314281 does not have P measures tensorized
# 6020326 does not have P measures tensorized
# 2324019 does not have P measures tensorized
# 4161301 does not have P measures tensorized
# 1897154 does not have P measures tensorized
# 3333119 does not have P measures tensorized
# 1401944 does not have P measures tensorized
# 2164162 does not have P measures tensorized
# 5557436 does not have P measures tensorized
# 4642618 does not have P measures tensorized
# 1341929 does not have P measures tensorized
# 3530895 does not have P measures tensorized
# 1311558 does not have P measures tensorized
# 2385688 does not have P measures tensorized
# 1701544 does not have P measures tensorized
# 3925878 does not have P measures tensorized
# 4654933 does not have P measures tensorized
# 3418416 does not have P measures tensorized
# 2729929 does not have P measures tensorized
# 4808587 does not have P measures tensorized
# 2520425 does not have P measures tensorized
# 2960296 does not have P measures tensorized
# 3184745 does not have P measures tensorized
# 5361108 does not have P measures tensorized
# 1842694 does not have P measures tensorized
# 4329749 does not have P measures tensorized
# 2360089 does not have RR measure tensorized
# 2360089 does not have PP measure tensorized
# 2360089 does not have P measures tensorized
# 2360089 does not have QRS measures tensorized
# 2360089 does not have R and T axis measures tensorized
# 4565926 does not have P measures tensorized
# 3861191 does not have P measures tensorized
# 2104502 does not have P measures tensorized
# 1961738 does not have P measures tensorized
# 5964398 does not have P measures tensorized
# 4352531 does not have P measures tensorized
# 5582661 does not have P measures tensorized
# 2208701 does not have P measures tensorized
# 5732713 does not have P measures tensorized
# 3350225 does not have P measures tensorized
# 2232981 does not have P measures tensorized
# 3120252 does not have P measures tensorized
# 3586008 does not have P measures tensorized
# 3738805 does not have P measures tensorized
# 1577838 does not have P measures tensorized
# 3775455 does not have P measures tensorized
# 5672496 does not have P measures tensorized
# 1231765 does not have P measures tensorized
# 2608915 does not have P measures tensorized
# 4127694 does not have P measures tensorized
# 3752922 does not have P measures tensorized
# 2649587 does not have P measures tensorized
# 2273921 does not have P measures tensorized
# 4309161 does not have P measures tensorized
# 5732991 does not have P measures tensorized
# 3733817 does not have P measures tensorized
# 3087654 does not have P measures tensorized
# 2257347 does not have P measures tensorized
# 4534377 does not have P measures tensorized
# 5829207 does not have P measures tensorized
# 3978281 does not have P measures tensorized
# 3662128 does not have P measures tensorized
# 5661262 does not have P measures tensorized
# 4096102 does not have P measures tensorized
# 2671693 does not have P measures tensorized
# 5360434 does not have P measures tensorized
# 3127526 does not have P measures tensorized
# 5076372 does not have P measures tensorized
# 4330318 does not have P measures tensorized
# 2276114 does not have P measures tensorized
# 5045162 does not have P measures tensorized
# 4344121 does not have P measures tensorized
# 5228622 does not have P measures tensorized
# 4554913 does not have P measures tensorized
# 3837568 does not have P measures tensorized
# 5628578 does not have P measures tensorized
# 4126831 does not have P measures tensorized
# 3405769 does not have P measures tensorized
# 3132564 does not have P measures tensorized
# 2011066 does not have P measures tensorized
# 1281325 does not have P measures tensorized
# 1493337 does not have P measures tensorized
# 4752485 does not have P measures tensorized
# 4787352 does not have P measures tensorized
# 4781624 does not have P measures tensorized
# 2441832 does not have P measures tensorized
# 3535244 does not have P measures tensorized
# 1244815 does not have P measures tensorized
# 4221374 does not have P measures tensorized
# 1297016 does not have P measures tensorized
# 3477985 does not have P measures tensorized
# 4655221 does not have P measures tensorized
# 5478709 does not have P measures tensorized
# 2646143 does not have P measures tensorized
# 3620768 does not have P measures tensorized
# 5180543 does not have P measures tensorized
# 3468528 does not have P measures tensorized
# 5397481 does not have P measures tensorized
# 4632924 does not have P measures tensorized
# 2464496 does not have P measures tensorized
# 5214985 does not have P measures tensorized
# 2152858 does not have P measures tensorized
# 4851129 does not have P measures tensorized
# 3063426 does not have P measures tensorized
# 5613504 does not have P measures tensorized
# 3162805 does not have P measures tensorized
# 3877551 does not have P measures tensorized
# 4136904 does not have P measures tensorized
# 2033527 does not have P measures tensorized
# 3628356 does not have P measures tensorized
# 5187181 does not have P measures tensorized
# 4006301 does not have P measures tensorized
# 3061968 does not have P measures tensorized
# 2576405 does not have P measures tensorized
# 5994404 does not have P measures tensorized
# 1818833 does not have P measures tensorized
# 5997524 does not have P measures tensorized
# 5118991 does not have P measures tensorized
# 4484243 does not have P measures tensorized
# 3443475 does not have P measures tensorized
# 5130297 does not have P measures tensorized
# 1090793 does not have P measures tensorized
# 4681523 does not have P measures tensorized
# 1792004 does not have P measures tensorized
# 5894242 does not have P measures tensorized
# 5926298 does not have P measures tensorized
# 4876809 does not have P measures tensorized
# 3686601 does not have P measures tensorized
# 1466054 does not have P measures tensorized
# 1459167 does not have P measures tensorized
# 5120495 does not have P measures tensorized
# 3992188 does not have P measures tensorized
# 3270043 does not have P measures tensorized
# 1714437 does not have P measures tensorized
# 1933385 does not have P measures tensorized
# 5455419 does not have P measures tensorized
# 3775121 does not have P measures tensorized
# 3203337 does not have P measures tensorized
# 4365852 does not have P measures tensorized
# 2610715 does not have P measures tensorized
# 2939713 does not have P measures tensorized
# 4976407 does not have P measures tensorized
# 2743629 does not have P measures tensorized
# 4534511 does not have P measures tensorized
# 2591273 does not have P measures tensorized
# 4619109 does not have P measures tensorized
# 1655745 does not have P measures tensorized
# 5937072 does not have P measures tensorized
# 4706529 does not have P measures tensorized
# 5647484 does not have P measures tensorized
# 2445357 does not have P measures tensorized
# 1856772 does not have P measures tensorized
# 5481759 does not have P measures tensorized
# 4040891 does not have P measures tensorized
# 3071929 does not have P measures tensorized
# 1927262 does not have P measures tensorized
# 1424696 does not have RR measure tensorized
# 1424696 does not have PP measure tensorized
# 1424696 does not have P measures tensorized
# 1424696 does not have QRS measures tensorized
# 1424696 does not have R and T axis measures tensorized
# 2286603 does not have P measures tensorized
# 2904337 does not have P measures tensorized
# 5948968 does not have P measures tensorized
# 3751599 does not have P measures tensorized
# 1616461 does not have P measures tensorized
# 5223613 does not have P measures tensorized
# 3552028 does not have P measures tensorized
# 3391039 does not have P measures tensorized
# 4459982 does not have P measures tensorized
# 4927173 does not have P measures tensorized
# 1156908 does not have P measures tensorized
# 2641136 does not have P measures tensorized
# 2051562 does not have P measures tensorized
# 3818903 does not have P measures tensorized
# 2543539 does not have P measures tensorized
# 2494199 does not have P measures tensorized
# 3363625 does not have P measures tensorized
# 4802435 does not have P measures tensorized
# 3663355 does not have P measures tensorized
# 1001187 does not have P measures tensorized
# 1701022 does not have P measures tensorized
# 3567718 does not have P measures tensorized
# 3553055 does not have P measures tensorized
# 1332157 does not have P measures tensorized
# 5307568 does not have P measures tensorized
# 2190832 does not have P measures tensorized
# 1945453 does not have P measures tensorized
# 3591999 does not have P measures tensorized
# 5348703 does not have P measures tensorized
# 1621961 does not have P measures tensorized
# 5960978 does not have P measures tensorized
# 5415086 does not have P measures tensorized
# 2080003 does not have P measures tensorized
# 4291188 does not have P measures tensorized
# 3272157 does not have P measures tensorized
# 1358677 does not have P measures tensorized
# 5255959 does not have P measures tensorized
# 1908533 does not have P measures tensorized
# 1179476 does not have P measures tensorized
# 2993276 does not have P measures tensorized
# 2841959 does not have P measures tensorized
# 3893441 does not have P measures tensorized
# 4498737 does not have P measures tensorized
# 5887537 does not have P measures tensorized
# 3295669 does not have P measures tensorized
# 5981946 does not have P measures tensorized
# 1441038 does not have P measures tensorized
# 4007633 does not have P measures tensorized
# 3249846 does not have P measures tensorized
# 1893678 does not have P measures tensorized
# 1686886 does not have P measures tensorized
# 5257295 does not have P measures tensorized
# 4836835 does not have P measures tensorized
# 1980051 does not have P measures tensorized
# 4625005 does not have P measures tensorized
# 3076517 does not have P measures tensorized
# 3564281 does not have P measures tensorized
# 5363512 does not have P measures tensorized
# 1732294 does not have P measures tensorized
# 2976205 does not have P measures tensorized
# 2254084 does not have P measures tensorized
# 1349552 does not have P measures tensorized
# 1009497 does not have P measures tensorized
# 2219558 does not have P measures tensorized
# 5627247 does not have P measures tensorized
# 3331206 does not have P measures tensorized
# 1362954 does not have P measures tensorized
# 1629674 does not have P measures tensorized
# 1123334 does not have P measures tensorized
# 1304066 does not have P measures tensorized
# 3645887 does not have P measures tensorized
# 1381284 does not have P measures tensorized
# 5432486 does not have P measures tensorized
# 4022277 does not have P measures tensorized
# 2081172 does not have P measures tensorized
# 5613299 does not have P measures tensorized
# 4894596 does not have P measures tensorized
# 3529321 does not have P measures tensorized
# 3486399 does not have P measures tensorized
# 4500429 does not have P measures tensorized
# 1999267 does not have P measures tensorized
# 1780316 does not have P measures tensorized
# 4484155 does not have P measures tensorized
# 1032183 does not have P measures tensorized
# 3663277 does not have P measures tensorized
# 2535783 does not have P measures tensorized
# 1959576 does not have P measures tensorized
# 5070895 does not have P measures tensorized
# 2713616 does not have P measures tensorized
# 1418008 does not have P measures tensorized
# 3674743 does not have P measures tensorized
# 4340009 does not have P measures tensorized
# 2687143 does not have P measures tensorized
# 4159755 does not have P measures tensorized
# 5205901 does not have P measures tensorized
# 5329683 does not have P measures tensorized
# 4048429 does not have P measures tensorized
# 2827861 does not have P measures tensorized
# 4623558 does not have P measures tensorized
# 5138509 does not have P measures tensorized
# 3780882 does not have P measures tensorized
# 2380291 does not have P measures tensorized
# 1854463 does not have P measures tensorized
# 3028664 does not have P measures tensorized
# 1216982 does not have P measures tensorized
# 1632204 does not have P measures tensorized
# 3293678 does not have P measures tensorized
# 3720617 does not have P measures tensorized
# 5936149 does not have P measures tensorized
# 4610264 does not have P measures tensorized
# 4083339 does not have P measures tensorized
# 1326322 does not have P measures tensorized
# 5483324 does not have P measures tensorized
# 1947781 does not have P measures tensorized
# 3856956 does not have P measures tensorized
# 3391368 does not have P measures tensorized
# 3294439 does not have P measures tensorized
# 3918923 does not have P measures tensorized
# 3618161 does not have P measures tensorized
# 3268038 does not have P measures tensorized
# 4695629 does not have P measures tensorized
# 4968104 does not have P measures tensorized
# 2750969 does not have P measures tensorized
# 1234097 does not have P measures tensorized
# 1848974 does not have P measures tensorized
# 2939529 does not have P measures tensorized
# 4708603 does not have P measures tensorized
# 1311225 does not have P measures tensorized
# 3589131 does not have P measures tensorized
# 4099682 does not have P measures tensorized
# 3500288 does not have P measures tensorized
# 2830029 does not have P measures tensorized
# 3400884 does not have P measures tensorized
# 3662315 does not have P measures tensorized
# 2883393 does not have P measures tensorized
# 2849224 does not have P measures tensorized
# 1589476 does not have P measures tensorized
# 5871111 does not have P measures tensorized
# 3436513 does not have P measures tensorized
# 3371042 does not have P measures tensorized
# 4157981 does not have P measures tensorized
# 5019585 does not have P measures tensorized
# 1579534 does not have P measures tensorized
# 4703601 does not have P measures tensorized
# 1694079 does not have P measures tensorized
# 4763061 does not have P measures tensorized
# 1600463 does not have P measures tensorized
# 4560892 does not have P measures tensorized
# 1300825 does not have P measures tensorized
# 3811889 does not have P measures tensorized
# 4585358 does not have P measures tensorized
# 5097383 does not have P measures tensorized
# 2734252 does not have P measures tensorized
# 3635879 does not have P measures tensorized
# 4128137 does not have P measures tensorized
# 4288688 does not have P measures tensorized
# 1449356 does not have P measures tensorized
# 2131554 does not have P measures tensorized
# 3708315 does not have P measures tensorized
# 5305763 does not have P measures tensorized
# 3874893 does not have P measures tensorized
# 2585719 does not have P measures tensorized
# 1117411 does not have P measures tensorized
# 5978327 does not have P measures tensorized
# 1186646 does not have P measures tensorized
# 3368001 does not have P measures tensorized
# 4496598 does not have P measures tensorized
# 1247087 does not have P measures tensorized
# 4241533 does not have P measures tensorized
# 1527891 does not have P measures tensorized
# 3027017 does not have P measures tensorized
# 4605093 does not have P measures tensorized
# 3742231 does not have P measures tensorized
# 2406725 does not have P measures tensorized
# 3196897 does not have P measures tensorized
# 4278165 does not have P measures tensorized
# 4467865 does not have P measures tensorized
# 1295841 does not have P measures tensorized
# 3372911 does not have P measures tensorized
# 2563813 does not have P measures tensorized
# 3281112 does not have P measures tensorized
# 2535472 does not have P measures tensorized
# 2165786 does not have P measures tensorized
# 3767042 does not have P measures tensorized
# 2442523 does not have P measures tensorized
# 3179622 does not have P measures tensorized
# 1733191 does not have P measures tensorized
# 4314865 does not have P measures tensorized
# 4688095 does not have P measures tensorized
# 4026766 does not have P measures tensorized
# 5519444 does not have P measures tensorized
# 2663424 does not have P measures tensorized
# 3317304 does not have P measures tensorized
# 3884558 does not have P measures tensorized
# 2528165 does not have P measures tensorized
# 1630559 does not have P measures tensorized
# 5596857 does not have P measures tensorized
# 5223957 does not have P measures tensorized
# 5427368 does not have P measures tensorized
# 4809775 does not have P measures tensorized
# 1641103 does not have P measures tensorized
# 4886092 does not have P measures tensorized
# 2051389 does not have P measures tensorized
# 3162982 does not have P measures tensorized
# 2753048 does not have P measures tensorized
# 4943146 does not have P measures tensorized
# 4562896 does not have P measures tensorized
# 1513594 does not have P measures tensorized
# 1069732 does not have P measures tensorized
# 1242451 does not have P measures tensorized
# 3917518 does not have P measures tensorized
# 3818748 does not have P measures tensorized
# 1506884 does not have P measures tensorized
# 3456532 does not have P measures tensorized
# 5667713 does not have P measures tensorized
# 5261974 does not have P measures tensorized
# 4662159 does not have P measures tensorized
# 2925715 does not have P measures tensorized
# 5420193 does not have P measures tensorized
# 1737863 does not have P measures tensorized
# 2086872 does not have P measures tensorized
# 1252895 does not have P measures tensorized
# 5685511 does not have P measures tensorized
# 4100731 does not have P measures tensorized
# 1793404 does not have P measures tensorized
# 1953397 does not have P measures tensorized
# 5680983 does not have P measures tensorized
# 1887507 does not have P measures tensorized
# 1435065 does not have P measures tensorized
# 4515039 does not have P measures tensorized
# 4684052 does not have P measures tensorized
# 5102669 does not have P measures tensorized
# 4929429 does not have P measures tensorized
# 5967283 does not have P measures tensorized
# 3414316 does not have P measures tensorized
# 4813746 does not have P measures tensorized
# 2608207 does not have P measures tensorized
# 2705591 does not have P measures tensorized
# 5357722 does not have P measures tensorized
# 5236015 does not have P measures tensorized
# 5641017 does not have P measures tensorized
# 2287155 does not have P measures tensorized
# 2919247 does not have P measures tensorized
# 4688714 does not have P measures tensorized
# 1840268 does not have P measures tensorized
# 4935587 does not have P measures tensorized
# 1999797 does not have P measures tensorized
# 3474183 does not have P measures tensorized
# 2924436 does not have P measures tensorized
# 4526528 does not have P measures tensorized
# 1546536 does not have P measures tensorized
# 5848949 does not have P measures tensorized
# 1577684 does not have P measures tensorized
# 3823038 does not have P measures tensorized
# 1426815 does not have P measures tensorized
# 5024818 does not have P measures tensorized
# 5979998 does not have P measures tensorized
# 4506999 does not have P measures tensorized
# 3710665 does not have P measures tensorized
# 4518886 does not have P measures tensorized
# 2586464 does not have P measures tensorized
# 1910029 does not have P measures tensorized
# 2578645 does not have P measures tensorized
# 1158616 does not have P measures tensorized
# 2061587 does not have P measures tensorized
# 1331554 does not have P measures tensorized
# 4174904 does not have P measures tensorized
# 2398008 does not have P measures tensorized
# 5330504 does not have P measures tensorized
# 2884034 does not have P measures tensorized
# 5043453 does not have P measures tensorized
# 5478496 does not have P measures tensorized
# 1121145 does not have P measures tensorized
# 2618831 does not have P measures tensorized
# 3483736 does not have P measures tensorized
# 3276608 does not have P measures tensorized
# 4514284 does not have P measures tensorized
# 4069134 does not have P measures tensorized
# 2650997 does not have P measures tensorized
# 3030718 does not have P measures tensorized
# 4938632 does not have P measures tensorized
# 1628611 does not have P measures tensorized
# 5696928 does not have P measures tensorized
# 4070017 does not have P measures tensorized
# 5194272 does not have P measures tensorized
# 4624531 does not have P measures tensorized
# 2467685 does not have P measures tensorized
# 5110307 does not have P measures tensorized
# 2798222 does not have P measures tensorized
# 2453197 does not have P measures tensorized
# 5395685 does not have P measures tensorized
# 2548313 does not have P measures tensorized
# 1341035 does not have P measures tensorized
# 2987235 does not have P measures tensorized
# 2829753 does not have P measures tensorized
# 5865453 does not have P measures tensorized
# 5857575 does not have P measures tensorized
# 5192136 does not have P measures tensorized
# 5830275 does not have P measures tensorized
# 5018223 does not have P measures tensorized
# 1157538 does not have P measures tensorized
# 4064172 does not have P measures tensorized
# 4719084 does not have P measures tensorized
# 2282385 does not have P measures tensorized
# 1435622 does not have P measures tensorized
# 3565944 does not have P measures tensorized
# 2838584 does not have P measures tensorized
# 4599913 does not have P measures tensorized
# 5153163 does not have P measures tensorized
# 1902836 does not have P measures tensorized
# 3403037 does not have P measures tensorized
# 2144445 does not have P measures tensorized
# 5854775 does not have P measures tensorized
# 5180744 does not have P measures tensorized
# 5017224 does not have P measures tensorized
# 5961404 does not have P measures tensorized
# 1547098 does not have P measures tensorized
# 1767593 does not have P measures tensorized
# 1214281 does not have P measures tensorized
# 3286234 does not have P measures tensorized
# 3127766 does not have P measures tensorized
# 4600545 does not have P measures tensorized
# 1847453 does not have P measures tensorized
# 1651556 does not have P measures tensorized
# 1324668 does not have P measures tensorized
# 4690477 does not have P measures tensorized
# 2025857 does not have P measures tensorized
# 2129369 does not have P measures tensorized
# 3727472 does not have P measures tensorized
# 4435286 does not have P measures tensorized
# 1837498 does not have P measures tensorized
# 1279917 does not have P measures tensorized
# 2503139 does not have P measures tensorized
# 3075728 does not have P measures tensorized
# 5859118 does not have P measures tensorized
# 4266431 does not have P measures tensorized
# 3844398 does not have P measures tensorized
# 3051993 does not have P measures tensorized
# 2610677 does not have P measures tensorized
# 1221257 does not have P measures tensorized
# 3695865 does not have P measures tensorized
# 3846791 does not have P measures tensorized
# 3931181 does not have P measures tensorized
# 2489775 does not have P measures tensorized
# 1886726 does not have P measures tensorized
# 4627123 does not have P measures tensorized
# 4497923 does not have P measures tensorized
# 4212078 does not have P measures tensorized
# 2381279 does not have P measures tensorized
# 4608226 does not have P measures tensorized
# 3058802 does not have P measures tensorized
# 2052289 does not have P measures tensorized
# 3143788 does not have P measures tensorized
# 2070874 does not have P measures tensorized
# 3891653 does not have P measures tensorized
# 4171739 does not have P measures tensorized
# 4798684 does not have P measures tensorized
# 5271735 does not have P measures tensorized
# 2559942 does not have P measures tensorized
# 3798413 does not have P measures tensorized
# 3490395 does not have P measures tensorized
# 4520336 does not have P measures tensorized
# 3908813 does not have P measures tensorized
# 3818861 does not have P measures tensorized
# 5428557 does not have P measures tensorized
# 2178854 does not have P measures tensorized
# 2953877 does not have P measures tensorized
# 3409894 does not have P measures tensorized
# 5935293 does not have P measures tensorized
# 3947993 does not have P measures tensorized
# 3563635 does not have P measures tensorized
# 1004466 does not have P measures tensorized
# 2186898 does not have P measures tensorized
# 1751701 does not have P measures tensorized
# 4160596 does not have P measures tensorized
# 4611823 does not have P measures tensorized
# 4060562 does not have P measures tensorized
# 1509361 does not have P measures tensorized
# 3870907 does not have P measures tensorized
# 4434284 does not have P measures tensorized
# 3076951 does not have P measures tensorized
# 5410352 does not have P measures tensorized
# 4613134 does not have P measures tensorized
# 1495795 does not have P measures tensorized
# 1661344 does not have P measures tensorized
# 5956806 does not have P measures tensorized
# 1760556 does not have P measures tensorized
# 1446292 does not have P measures tensorized
# 2454343 does not have P measures tensorized
# 5079525 does not have P measures tensorized
# 4638544 does not have P measures tensorized
# 4861985 does not have P measures tensorized
# 2642359 does not have P measures tensorized
# 2071439 does not have P measures tensorized
# 2590468 does not have P measures tensorized
# 3174414 does not have P measures tensorized
# 3079161 does not have P measures tensorized
# 1935921 does not have P measures tensorized
# 1779984 does not have P measures tensorized
# 4263128 does not have P measures tensorized
# 2409171 does not have P measures tensorized
# 3146474 does not have P measures tensorized
# 2412256 does not have P measures tensorized
# 5480878 does not have P measures tensorized
# 1353377 does not have P measures tensorized
# 3958724 does not have P measures tensorized
# 2301776 does not have P measures tensorized
# 4652353 does not have P measures tensorized
# 4089966 does not have P measures tensorized
# 2417197 does not have P measures tensorized
# 4434877 does not have P measures tensorized
# 5320719 does not have P measures tensorized
# 2413043 does not have P measures tensorized
# 2928766 does not have P measures tensorized
# 1413941 does not have P measures tensorized
# 5793425 does not have P measures tensorized
# 2674388 does not have P measures tensorized
# 2259788 does not have P measures tensorized
# 2980472 does not have P measures tensorized
# 2856962 does not have P measures tensorized
# 4240373 does not have P measures tensorized
# 1203293 does not have P measures tensorized
# 4509948 does not have P measures tensorized
# 3162583 does not have P measures tensorized
# 1596459 does not have P measures tensorized
# 5033614 does not have P measures tensorized
# 5683642 does not have P measures tensorized
# 2678175 does not have P measures tensorized
# 3670825 does not have P measures tensorized
# 5558506 does not have P measures tensorized
# 5839922 does not have P measures tensorized
# 5877953 does not have P measures tensorized
# 1354488 does not have P measures tensorized
# 5770653 does not have P measures tensorized
# 3618025 does not have P measures tensorized
# 5110102 does not have P measures tensorized
# 5494876 does not have P measures tensorized
# 5804725 does not have P measures tensorized
# 4169688 does not have P measures tensorized
# 2242982 does not have P measures tensorized
# 5988347 does not have P measures tensorized
# 4487364 does not have P measures tensorized
# 2495382 does not have P measures tensorized
# 5160508 does not have P measures tensorized
# 4596365 does not have P measures tensorized
# 1599073 does not have P measures tensorized
# 2244857 does not have P measures tensorized
# 1514141 does not have P measures tensorized
# 1261769 does not have P measures tensorized
# 4271174 does not have P measures tensorized
# 4751643 does not have P measures tensorized
# 4967605 does not have P measures tensorized
# 3689178 does not have P measures tensorized
# 4004496 does not have P measures tensorized
# 3188793 does not have P measures tensorized
# 2257429 does not have P measures tensorized
# 2641389 does not have P measures tensorized
# 3714009 does not have P measures tensorized
# 5179019 does not have P measures tensorized
# 1509092 does not have P measures tensorized
# 2543366 does not have P measures tensorized
# 5096646 does not have P measures tensorized
# 5211727 does not have P measures tensorized
# 2885439 does not have P measures tensorized
# 4284357 does not have P measures tensorized
# 1404316 does not have P measures tensorized
# 2188337 does not have P measures tensorized
# 4804192 does not have P measures tensorized
# 2116228 does not have P measures tensorized
# 4585127 does not have P measures tensorized
# 4694059 does not have P measures tensorized
# 4962692 does not have P measures tensorized
# 5377177 does not have P measures tensorized
# 2220732 does not have P measures tensorized
# 3623817 does not have P measures tensorized
# 3614322 does not have P measures tensorized
# 3860901 does not have P measures tensorized
# 1930707 does not have P measures tensorized
# 3021439 does not have P measures tensorized
# 4423007 does not have P measures tensorized
# 4651615 does not have P measures tensorized
# 5062015 does not have P measures tensorized
# 5354762 does not have P measures tensorized
# 4150762 does not have P measures tensorized
# 3557301 does not have P measures tensorized
# 2185539 does not have P measures tensorized
# 5325632 does not have P measures tensorized
# 5261445 does not have P measures tensorized
# 2203882 does not have P measures tensorized
# 2395025 does not have P measures tensorized
# 4317373 does not have P measures tensorized
# 1426355 does not have P measures tensorized
# 3321521 does not have P measures tensorized
# 3281555 does not have P measures tensorized
# 3729241 does not have P measures tensorized
# 2911057 does not have P measures tensorized
# 2588875 does not have P measures tensorized
# 5231979 does not have P measures tensorized
# 5326022 does not have P measures tensorized
# 5850604 does not have P measures tensorized
# 4823555 does not have P measures tensorized
# 5292804 does not have P measures tensorized
# 4734335 does not have P measures tensorized
# 5167409 does not have P measures tensorized
# 3505658 does not have P measures tensorized
# 4165954 does not have P measures tensorized
# 1706246 does not have P measures tensorized
# 1267668 does not have P measures tensorized
# 2776421 does not have P measures tensorized
# 2753811 does not have P measures tensorized
# 3742099 does not have P measures tensorized
# 4766236 does not have P measures tensorized
# 3118743 does not have P measures tensorized
# 5057311 does not have RR measure tensorized
# 5057311 does not have PP measure tensorized
# 5057311 does not have P measures tensorized
# 5057311 does not have QRS measures tensorized
# 5057311 does not have R and T axis measures tensorized
# 5115437 does not have P measures tensorized
# 2885234 does not have P measures tensorized
# 1376305 does not have P measures tensorized
# 3723116 does not have P measures tensorized
# 4515286 does not have P measures tensorized
# 2614327 does not have P measures tensorized
# 4932884 does not have P measures tensorized
# 1150114 does not have P measures tensorized
# 4310807 does not have P measures tensorized
# 3311262 does not have P measures tensorized
# 4605577 does not have P measures tensorized
# 4491538 does not have P measures tensorized
# 4898062 does not have P measures tensorized
# 4478107 does not have P measures tensorized
# 1284901 does not have P measures tensorized
# 1179278 does not have P measures tensorized
# 4481771 does not have P measures tensorized
# 3675729 does not have P measures tensorized
# 2597368 does not have P measures tensorized
# 5098401 does not have P measures tensorized
# 1427093 does not have P measures tensorized
# 2397507 does not have P measures tensorized
# 2154011 does not have P measures tensorized
# 1619864 does not have P measures tensorized
# 5236232 does not have P measures tensorized
# 2655208 does not have P measures tensorized
# 5530904 does not have P measures tensorized
# 3808849 does not have P measures tensorized
# 3432363 does not have P measures tensorized
# 2325276 does not have P measures tensorized
# 3949124 does not have P measures tensorized
# 3543226 does not have P measures tensorized
# 1728047 does not have P measures tensorized
# 5436788 does not have P measures tensorized
# 3010248 does not have P measures tensorized
# 1814637 does not have P measures tensorized
# 3126578 does not have P measures tensorized
# 2053454 does not have P measures tensorized
# 4684546 does not have P measures tensorized
# 4686499 does not have P measures tensorized
# 3119007 does not have P measures tensorized
# 5225066 does not have P measures tensorized
# 1975853 does not have P measures tensorized
# 1858095 does not have P measures tensorized
# 4199131 does not have P measures tensorized
# 2890804 does not have P measures tensorized
# 4957502 does not have P measures tensorized
# 2734941 does not have P measures tensorized
# 1657684 does not have P measures tensorized
# 3721612 does not have P measures tensorized
# 1773184 does not have P measures tensorized
# 4060215 does not have P measures tensorized
# 3962995 does not have P measures tensorized
# 1060227 does not have P measures tensorized
# 5130713 does not have P measures tensorized
# 4036475 does not have RR measure tensorized
# 4036475 does not have PP measure tensorized
# 4036475 does not have P measures tensorized
# 4036475 does not have QRS measures tensorized
# 4036475 does not have R and T axis measures tensorized
# 4264167 does not have P measures tensorized
# 5399692 does not have P measures tensorized
# 4742177 does not have P measures tensorized
# 5123596 does not have P measures tensorized
# 3467043 does not have P measures tensorized
# 5429823 does not have P measures tensorized
# 4302569 does not have P measures tensorized
# 4951389 does not have P measures tensorized
# 3031617 does not have P measures tensorized
# 2991719 does not have P measures tensorized
# 5866712 does not have P measures tensorized
# 2614088 does not have P measures tensorized
# 4755041 does not have P measures tensorized
# 3321032 does not have P measures tensorized
# 6020873 does not have RR measure tensorized
# 6020873 does not have PP measure tensorized
# 6020873 does not have P measures tensorized
# 6020873 does not have QRS measures tensorized
# 6020873 does not have R and T axis measures tensorized
# 3895662 does not have P measures tensorized
# 5752705 does not have P measures tensorized
# 3960471 does not have P measures tensorized
# 3062564 does not have P measures tensorized
# 4614994 does not have P measures tensorized
# 3363539 does not have P measures tensorized
# 1809348 does not have P measures tensorized
# 1276377 does not have P measures tensorized
# 1022535 does not have P measures tensorized
# 4869008 does not have P measures tensorized
# 4854891 does not have P measures tensorized
# 2802498 does not have P measures tensorized
# 4634412 does not have P measures tensorized
# 1723645 does not have P measures tensorized
# 4391967 does not have P measures tensorized
# 5456197 does not have P measures tensorized
# 2719816 does not have P measures tensorized
# 3218059 does not have RR measure tensorized
# 3218059 does not have PP measure tensorized
# 3218059 does not have P measures tensorized
# 3218059 does not have QRS measures tensorized
# 3218059 does not have R and T axis measures tensorized
# 1388378 does not have P measures tensorized
# 4448922 does not have P measures tensorized
# 1564673 does not have P measures tensorized
# 1616127 does not have P measures tensorized
# 2531696 does not have P measures tensorized
# 3687401 does not have P measures tensorized
# 5380018 does not have P measures tensorized
# 1600094 does not have P measures tensorized
# 4714046 does not have P measures tensorized
# 1014882 does not have P measures tensorized
# 2155168 does not have P measures tensorized
# 2736925 does not have P measures tensorized
# 1076628 does not have P measures tensorized
# 4931226 does not have P measures tensorized
# 1183183 does not have P measures tensorized
# 5769635 does not have P measures tensorized
# 5600339 does not have P measures tensorized
# 4541008 does not have P measures tensorized
# 5815619 does not have P measures tensorized
# 1356487 does not have P measures tensorized
# 5899869 does not have P measures tensorized
# 5630971 does not have P measures tensorized
# 1771018 does not have P measures tensorized
# 1471132 does not have P measures tensorized
# 3117133 does not have P measures tensorized
# 2618481 does not have P measures tensorized
# 4074355 does not have P measures tensorized
# 1884479 does not have P measures tensorized
# 1286106 does not have P measures tensorized
# 2301911 does not have P measures tensorized
# 3892892 does not have P measures tensorized
# 4028659 does not have P measures tensorized
# 3827308 does not have P measures tensorized
# 5525016 does not have P measures tensorized
# 1939693 does not have P measures tensorized
# 5607069 does not have P measures tensorized
# 3904719 does not have P measures tensorized
# 4732118 does not have P measures tensorized
# 2438503 does not have P measures tensorized
# 4260352 does not have P measures tensorized
# 4898854 does not have P measures tensorized
# 3956923 does not have P measures tensorized
# 1649891 does not have P measures tensorized
# 3424073 does not have P measures tensorized
# 3602882 does not have P measures tensorized
# 4997586 does not have P measures tensorized
# 4165604 does not have P measures tensorized
# 4841927 does not have P measures tensorized
# 2783137 does not have P measures tensorized
# 4080485 does not have P measures tensorized
# 5200412 does not have P measures tensorized
# 2712973 does not have P measures tensorized
# 2163069 does not have P measures tensorized
# 3138067 does not have P measures tensorized
# 3537215 does not have P measures tensorized
# 3053576 does not have P measures tensorized
# 5910106 does not have P measures tensorized
# 5522599 does not have P measures tensorized
# 3857897 does not have P measures tensorized
# 5733732 does not have P measures tensorized
# 4844162 does not have P measures tensorized
# 1095204 does not have P measures tensorized
# 5826229 does not have P measures tensorized
# 1108827 does not have P measures tensorized
# 5029066 does not have P measures tensorized
# 3995632 does not have P measures tensorized
# 1650119 does not have P measures tensorized
# 4436637 does not have P measures tensorized
# 3194063 does not have P measures tensorized
# 2298775 does not have P measures tensorized
# 3922758 does not have P measures tensorized
# 3409223 does not have P measures tensorized
# 1737074 does not have P measures tensorized
# 3288404 does not have P measures tensorized
# 3527081 does not have P measures tensorized
# 4987069 does not have P measures tensorized
# 3760079 does not have P measures tensorized
# 5868586 does not have P measures tensorized
# 1424785 does not have P measures tensorized
# 1305773 does not have P measures tensorized
# 5035161 does not have P measures tensorized
# 1975424 does not have P measures tensorized
# 1584537 does not have P measures tensorized
# 1719189 does not have P measures tensorized
# 5810052 does not have P measures tensorized
# 3801172 does not have P measures tensorized
# 3092678 does not have P measures tensorized
# 2840069 does not have P measures tensorized
# 2092249 does not have P measures tensorized
# 5238109 does not have P measures tensorized
# 5669246 does not have P measures tensorized
# 1001278 does not have P measures tensorized
# 2900261 does not have P measures tensorized
# 5272786 does not have P measures tensorized
# 1151147 does not have P measures tensorized
# 3936072 does not have P measures tensorized
# 3214936 does not have P measures tensorized
# 1204969 does not have P measures tensorized
# 1573992 does not have P measures tensorized
# 2015874 does not have P measures tensorized
# 1339779 does not have P measures tensorized
# 6017384 does not have P measures tensorized
# 2532557 does not have P measures tensorized
# 1119274 does not have P measures tensorized
# 3794144 does not have P measures tensorized
# 1086694 does not have P measures tensorized
# 1998113 does not have P measures tensorized
# 2601534 does not have P measures tensorized
# 5454004 does not have P measures tensorized
# 5540487 does not have P measures tensorized
# 5991131 does not have P measures tensorized
# 3533407 does not have P measures tensorized
# 3527135 does not have P measures tensorized
# 1839424 does not have P measures tensorized
# 4371518 does not have P measures tensorized
# 1752026 does not have P measures tensorized
# 1045846 does not have P measures tensorized
# 2454762 does not have P measures tensorized
# 3972931 does not have P measures tensorized
# 1298634 does not have P measures tensorized
# 3252066 does not have P measures tensorized
# 3075795 does not have P measures tensorized
# 2195111 does not have P measures tensorized
# 2079855 does not have P measures tensorized
# 1166493 does not have P measures tensorized
# ...
# 3967970 does not have P measures tensorized
# 5204381 does not have P measures tensorized
# 4551560 does not have P measures tensorized
# 1387629 does not have P measures tensorized
# 3475424 does not have P measures tensorized
# 1572240 does not have P measures tensorized
# 2306126 does not have P measures tensorized
# 2165839 does not have P measures tensorized
# 3879800 does not have P measures tensorized
# 3757848 does not have P measures tensorized
# 4441931 does not have P measures tensorized
# 5240555 does not have P measures tensorized
# 3805320 does not have P measures tensorized
# 3107990 does not have P measures tensorized
# 3238030 does not have P measures tensorized
# 5945805 does not have P measures tensorized
# 4939868 does not have P measures tensorized
# 1866921 does not have P measures tensorized
# 3122275 does not have P measures tensorized
# 4881950 does not have P measures tensorized
# 4863270 does not have P measures tensorized
# 1413790 does not have P measures tensorized
# 1676629 does not have P measures tensorized
# 3725470 does not have P measures tensorized
# 2702180 does not have P measures tensorized
# 3589872 does not have P measures tensorized
# 1341703 does not have P measures tensorized
# 5724693 does not have P measures tensorized
# 3672140 does not have P measures tensorized
# 4406020 does not have P measures tensorized
# 4538123 does not have P measures tensorized
# 4807020 does not have P measures tensorized
# 3721400 does not have P measures tensorized
# 2606755 does not have P measures tensorized
# 3935375 does not have P measures tensorized
# 2251179 does not have P measures tensorized
# 6005417 does not have P measures tensorized
# 2797202 does not have P measures tensorized
# 5119320 does not have P measures tensorized
# 3394190 does not have P measures tensorized
# 2315265 does not have P measures tensorized
# 1602343 does not have P measures tensorized
# 1471269 does not have P measures tensorized
# 3868629 does not have P measures tensorized
# 4473031 does not have P measures tensorized
# 4913880 does not have P measures tensorized
# 2201270 does not have P measures tensorized
# 5950590 does not have RR measure tensorized
# 5950590 does not have PP measure tensorized
# 5950590 does not have P measures tensorized
# 5950590 does not have QRS measures tensorized
# 5950590 does not have R and T axis measures tensorized
# 1980630 does not have P measures tensorized
# 3002101 does not have P measures tensorized
# 4797494 does not have P measures tensorized
# 3078963 does not have P measures tensorized
# 3164760 does not have P measures tensorized
# 3623603 does not have P measures tensorized
# 1009073 does not have P measures tensorized
# 3658500 does not have P measures tensorized
# 1477910 does not have P measures tensorized
# 3287837 does not have P measures tensorized
# 3166880 does not have P measures tensorized
# 4177330 does not have P measures tensorized
# 3470220 does not have P measures tensorized
# 1586178 does not have P measures tensorized
# 1474284 does not have P measures tensorized
# 5428510 does not have P measures tensorized
# 4822186 does not have P measures tensorized
# 3128650 does not have P measures tensorized
# 1944817 does not have P measures tensorized
# 4681241 does not have P measures tensorized
# 4493910 does not have P measures tensorized
# 3893435 does not have P measures tensorized
# 1118193 does not have P measures tensorized
# 5590720 does not have P measures tensorized
# 2442410 does not have P measures tensorized
# 2276299 does not have P measures tensorized
# 3162047 does not have P measures tensorized
# 5160080 does not have P measures tensorized
# 1651780 does not have P measures tensorized
# 1040320 does not have P measures tensorized
# 1581930 does not have P measures tensorized
# 2945490 does not have P measures tensorized
# 1782199 does not have RR measure tensorized
# 1782199 does not have PP measure tensorized
# 1782199 does not have P measures tensorized
# 1782199 does not have QRS measures tensorized
# 1782199 does not have R and T axis measures tensorized
# 2642900 does not have P measures tensorized
# 3478860 does not have P measures tensorized
# 1053790 does not have P measures tensorized
# 4712040 does not have P measures tensorized
# 3666385 does not have P measures tensorized
# 4341240 does not have P measures tensorized
# 2353380 does not have P measures tensorized
# 4077855 does not have P measures tensorized
# 5075490 does not have P measures tensorized
# 2838933 does not have P measures tensorized
# 5761076 does not have P measures tensorized
# 1968682 does not have P measures tensorized
# 1977820 does not have P measures tensorized
# 1188030 does not have P measures tensorized
# 1741643 does not have P measures tensorized
# 1360539 does not have P measures tensorized
# 2822960 does not have P measures tensorized
# 5983680 does not have P measures tensorized
# 4812320 does not have P measures tensorized
# 3559797 does not have P measures tensorized
# 2749189 does not have P measures tensorized
# 3687620 does not have P measures tensorized
# 2809020 does not have P measures tensorized
# 5469607 does not have P measures tensorized
# 2235070 does not have P measures tensorized
# 1849620 does not have P measures tensorized
# 3301735 does not have P measures tensorized
# 2740653 does not have P measures tensorized
# 5217367 does not have P measures tensorized
# 1059849 does not have P measures tensorized
# 4864810 does not have P measures tensorized
# 1757950 does not have P measures tensorized
# 4270280 does not have P measures tensorized
# 1039939 does not have P measures tensorized
# 5505327 does not have P measures tensorized
# 4359207 does not have P measures tensorized
# 4831989 does not have P measures tensorized
# 5482406 does not have P measures tensorized
# 2591210 does not have P measures tensorized
# 3727566 does not have P measures tensorized
# 3927400 does not have P measures tensorized
# 1903660 does not have P measures tensorized
# 5331390 does not have P measures tensorized
# 2539260 does not have P measures tensorized
# 4956996 does not have P measures tensorized
# 3524650 does not have P measures tensorized
# 4338960 does not have P measures tensorized
# 5311946 does not have P measures tensorized
# 5492250 does not have P measures tensorized
# 3616106 does not have P measures tensorized
# 1245029 does not have P measures tensorized
# 5973090 does not have P measures tensorized
# 5940396 does not have P measures tensorized
# 2688200 does not have P measures tensorized
# 4791299 does not have P measures tensorized
# 2431770 does not have P measures tensorized
# 2988760 does not have P measures tensorized
# 4111688 does not have P measures tensorized
# 4542440 does not have P measures tensorized
# 5754081 does not have P measures tensorized
# 1153270 does not have P measures tensorized
# 2051136 does not have P measures tensorized
# 1419078 does not have P measures tensorized
# 2606263 does not have P measures tensorized
# 5220922 does not have P measures tensorized
# 1671670 does not have P measures tensorized
# 3717930 does not have P measures tensorized
# 4835770 does not have P measures tensorized
# 1397032 does not have P measures tensorized
# 1002342 does not have P measures tensorized
# 1137420 does not have P measures tensorized
# 2629332 does not have P measures tensorized
# 1363396 does not have P measures tensorized
# 1535630 does not have P measures tensorized
# 4333038 does not have P measures tensorized
# 5933000 does not have P measures tensorized
# 3312211 does not have P measures tensorized
# 5626220 does not have P measures tensorized
# 5614694 does not have P measures tensorized
# 2350883 does not have P measures tensorized
# 1524050 does not have P measures tensorized
# 5952879 does not have P measures tensorized
# 3630310 does not have P measures tensorized
# 4502610 does not have P measures tensorized
# 1747860 does not have P measures tensorized
# 1964770 does not have P measures tensorized
# 5223105 does not have P measures tensorized
# 1781050 does not have P measures tensorized
# 1441440 does not have P measures tensorized
# 5836760 does not have P measures tensorized
# 2994080 does not have P measures tensorized
# 2991142 does not have P measures tensorized
# 5205973 does not have P measures tensorized
# 5473680 does not have P measures tensorized
# 4005548 does not have P measures tensorized
# 5828420 does not have P measures tensorized
# 1063130 does not have P measures tensorized
# 3382314 does not have P measures tensorized
# 4064180 does not have P measures tensorized
# 4037750 does not have P measures tensorized
# 4960930 does not have P measures tensorized
# 5731420 does not have P measures tensorized
# 4963290 does not have P measures tensorized
# 5953500 does not have P measures tensorized
# 5955930 does not have P measures tensorized
# 5258089 does not have P measures tensorized
# 2748630 does not have P measures tensorized
# 2136770 does not have P measures tensorized
# 5199041 does not have P measures tensorized
# 5225705 does not have P measures tensorized
# 1910950 does not have P measures tensorized
# 4672462 does not have P measures tensorized
# 1197090 does not have P measures tensorized
# 2756845 does not have P measures tensorized
# 1261626 does not have P measures tensorized
# 2248530 does not have P measures tensorized
# 2010420 does not have P measures tensorized
# 3914030 does not have P measures tensorized
# 1995680 does not have P measures tensorized
# 4327370 does not have P measures tensorized
# 1237313 does not have P measures tensorized
# 5648058 does not have P measures tensorized
# 3854970 does not have P measures tensorized
# 3683674 does not have P measures tensorized
# 1907403 does not have P measures tensorized
# 1670067 does not have P measures tensorized
# 5718902 does not have P measures tensorized
# 3851560 does not have P measures tensorized
# 2826640 does not have P measures tensorized
# 4406585 does not have P measures tensorized
# 1922569 does not have P measures tensorized
# 2879860 does not have P measures tensorized
# 2358653 does not have P measures tensorized
# 5994875 does not have P measures tensorized
# 4565456 does not have P measures tensorized
# 3674520 does not have P measures tensorized
# 4019680 does not have P measures tensorized
# 2265383 does not have RR measure tensorized
# 2265383 does not have PP measure tensorized
# 2265383 does not have P measures tensorized
# 2265383 does not have QRS measures tensorized
# 2265383 does not have R and T axis measures tensorized
# 5211498 does not have P measures tensorized
# 4124580 does not have P measures tensorized
# 1444960 does not have P measures tensorized
# 5642200 does not have P measures tensorized
# 5786110 does not have P measures tensorized
# 2751954 does not have P measures tensorized
# 4211630 does not have P measures tensorized
# 3584630 does not have P measures tensorized
# 3176220 does not have P measures tensorized
# 3498780 does not have P measures tensorized
# 2584770 does not have P measures tensorized
# 2557844 does not have P measures tensorized
# 4435330 does not have P measures tensorized
# 2617610 does not have P measures tensorized
# 4268000 does not have P measures tensorized
# 3919290 does not have P measures tensorized
# 5087430 does not have P measures tensorized
# 3849980 does not have P measures tensorized
# 2021579 does not have P measures tensorized
# 5411948 does not have P measures tensorized
# 3566330 does not have P measures tensorized
# 5493509 does not have P measures tensorized
# 3455283 does not have P measures tensorized
# 1975048 does not have P measures tensorized
# 4277691 does not have P measures tensorized
# 1453320 does not have P measures tensorized
# 2958110 does not have P measures tensorized
# 5018601 does not have P measures tensorized
# 3991830 does not have P measures tensorized
# 1572835 does not have P measures tensorized
# 3730160 does not have P measures tensorized
# 5814553 does not have P measures tensorized
# 2425290 does not have P measures tensorized
# 2716422 does not have P measures tensorized
# 5118479 does not have P measures tensorized
# 4166570 does not have P measures tensorized
# 2172191 does not have P measures tensorized
# 4197829 does not have P measures tensorized
# 4432806 does not have P measures tensorized
# 4684930 does not have P measures tensorized
# 1786599 does not have P measures tensorized
# 4628849 does not have P measures tensorized
# 3439620 does not have P measures tensorized
# 2416322 does not have P measures tensorized
# 2097410 does not have P measures tensorized
# 1144340 does not have P measures tensorized
# 5756993 does not have P measures tensorized
# 3426648 does not have P measures tensorized
# 3984732 does not have P measures tensorized
# 4487825 does not have P measures tensorized
# 3874180 does not have P measures tensorized
# 5407360 does not have P measures tensorized
# 3319020 does not have P measures tensorized
# 1291295 does not have P measures tensorized
# 1338630 does not have P measures tensorized
# 4583049 does not have P measures tensorized
# 5077140 does not have P measures tensorized
# 5032339 does not have P measures tensorized
# 4691990 does not have P measures tensorized
# 1611970 does not have P measures tensorized
# 4147190 does not have P measures tensorized
# 2328390 does not have P measures tensorized
# 5684251 does not have P measures tensorized
# 1194840 does not have P measures tensorized
# 5825587 does not have P measures tensorized
# 3884067 does not have P measures tensorized
# 5170910 does not have P measures tensorized
# 4260500 does not have P measures tensorized
# 2020820 does not have P measures tensorized
# 3647080 does not have P measures tensorized
# 2828050 does not have P measures tensorized
# 4748809 does not have P measures tensorized
# 3978260 does not have P measures tensorized
# 2553776 does not have P measures tensorized
# 5738619 does not have P measures tensorized
# 4235789 does not have P measures tensorized
# 5755370 does not have P measures tensorized
# 5949087 does not have P measures tensorized
# 3972182 does not have P measures tensorized
# 1703412 does not have P measures tensorized
# 4672086 does not have P measures tensorized
# 2360457 does not have P measures tensorized
# 1425760 does not have P measures tensorized
# 4807270 does not have P measures tensorized
# 5438500 does not have P measures tensorized
# 2416670 does not have P measures tensorized
# 1288874 does not have P measures tensorized
# 1109360 does not have P measures tensorized
# 4797844 does not have P measures tensorized
# 4526724 does not have P measures tensorized
# 5218160 does not have P measures tensorized
# 2744580 does not have P measures tensorized
# 1603791 does not have P measures tensorized
# 2390431 does not have P measures tensorized
# 5110370 does not have P measures tensorized
# 2775623 does not have P measures tensorized
# 4628643 does not have P measures tensorized
# 1235635 does not have P measures tensorized
# 1862188 does not have P measures tensorized
# 4307763 does not have P measures tensorized
# 1317486 does not have P measures tensorized
# 1378580 does not have P measures tensorized
# 3683770 does not have P measures tensorized
# 1553230 does not have P measures tensorized
# 4518258 does not have P measures tensorized
# 5009734 does not have P measures tensorized
# 1861173 does not have P measures tensorized
# 4192949 does not have P measures tensorized
# 1765830 does not have P measures tensorized
# 4285990 does not have P measures tensorized
# 3677630 does not have P measures tensorized
# 1266759 does not have P measures tensorized
# 3482880 does not have P measures tensorized
# 4723100 does not have P measures tensorized
# 4085610 does not have P measures tensorized
# 4396056 does not have P measures tensorized
# 3855848 does not have P measures tensorized
# 2474370 does not have P measures tensorized
# 4700249 does not have P measures tensorized
# 5367509 does not have P measures tensorized
# 4428072 does not have P measures tensorized
# 5423690 does not have P measures tensorized
# 5042700 does not have P measures tensorized
# 5003590 does not have P measures tensorized
# 5591663 does not have P measures tensorized
# 5019500 does not have P measures tensorized
# 4033437 does not have P measures tensorized
# 2928444 does not have P measures tensorized
# 4220925 does not have P measures tensorized
# 4009455 does not have P measures tensorized
# 4283388 does not have P measures tensorized

# %%
df = pd.DataFrame(df_dic)

# %%
# !pip install protobuf
# !pip install facets-overview

# %%
# # Create the feature stats for the datasets and stringify it.
# import base64
# from facets_overview.generic_feature_statistics_generator import GenericFeatureStatisticsGenerator

# gfsg = GenericFeatureStatisticsGenerator()
# proto = gfsg.ProtoFromDataFrames([{'name': 'train', 'table': df}])
# protostr = base64.b64encode(proto.SerializeToString()).decode("utf-8")

# %%
# # Display the facets overview visualization for this data
# from IPython.core.display import display, HTML

# HTML_TEMPLATE = f"""
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#         <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html" >
#         <facets-overview id="fo"></facets-overview>
#         <script>
#           document.querySelector("#fo").protoInput = "{protostr}";
#         </script>"""
# html = HTML_TEMPLATE.format(protostr=protostr)
# display(HTML(html))

# %%
# # Display the Dive visualization for this data
# from IPython.core.display import display, HTML

# sprite_size = 100
# # Create Facets template  
# HTML_TEMPLATE = """<link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
#         <facets-dive sprite-image-width="{sprite_size}" sprite-image-height="{sprite_size}" id="elem" height="600"></facets-dive>
#         <facets-overview id="fo"></facets-overview>
#         <script>
#           document.querySelector("#elem").data = {jsonstr};
#           document.querySelector("#fo").protoInput = "{protostr}";
#         </script>"""

# # Load the json dataset and the sprite_size into the template
# html = HTML_TEMPLATE.format(jsonstr=jsonstr, sprite_size=sprite_size, protostr=protostr)

# # Display the template
# display(HTML(html))

# %%
class ecg_class:
    def __init__(self, ecg_class_id, name=None):
        self.id = ecg_class_id
        self.name = name
        self.children = []
        self.children_ids = []
        self.matching_strings = []
        self.ncounts = 0
        self.level = 0
        self.patients = [] 
        self.class_df = None
        self.class_parents = []
    
    def __getitem__(self, key):        
        if key not in self.children_ids:
            raise KeyError(f'Class {key} is not a member of {self.id}')
        idx = self.children_ids.index(key)
        return self.children[idx]

    def __str__(self):
        tabs = '   '*self.level+'|_____' 
        return f'{tabs}{self.name}: {self.ncounts} ({self.ncounts / 37623.0 * 100.0 :.2f}%)'

    def __iter__(self):
        for child_id in self.children_ids:
            yield child_id

    def __contains__(self, key):        
        return key in self.children_ids
    
    def items(self):
        return [(k, self[k]) for k in self.children_ids]
    
    def keys(self):
        return self.children_ids
    
    def print_hierarchy(self):
        for k, v in self.items():
            print(v)
            if isinstance(v, ecg_class):
                v.print_hierarchy()
    
    def add_child(self, ecg_class):
        if ecg_class.id in self.children_ids:
            print("WARNING: class with same id already among subclasses. Skipping")
        else:
            self.children.append(ecg_class)
            self.children_ids.append(ecg_class.id)
            self.children[-1].level = self.level+1
            self.children[-1].class_parents = self.class_parents + [self.id]
            
    def add_matching_string(self, new_string):
        self.matching_strings.append(new_string)
        self.matching_strings = list(set(self.matching_strings))
        
    def make_children_exclusive(self, df):
        if not self.children:
            raise KeyError(f'Class {self.name} does not have subclasses. Use update_class_df instead')
        for child in self.children:
            if child.class_df is None:
                child.update_class_df(df)
        class_df = self.children[0].class_df
        for c2 in self.children[1:]:                
            inters = class_df.index.intersection(c2.class_df.index)
            c2.class_df = c2.class_df.drop(inters)
            c2.ncounts = len(c2.class_df)
            class_df = pd.concat([class_df, c2.class_df])
        self.class_df = class_df
        self.ncounts = len(class_df)

    def make_child_exclusive(self, child_id, df):
        if child_id not in self.children_ids:
            raise KeyError(f'Class {key} is not a member of {self.id}')
        child_idx = self.children_ids.index(child_id)
        child = self.children.pop(child_idx)
        self.children.append(child)
        class_df = self.children[0].class_df        
        for c2 in self.children[1:]:
            inters = class_df.index.intersection(c2.class_df.index)
            c2_class_df = c2.class_df.drop(inters)
            class_df = pd.concat([class_df, c2_class_df])
        c2.class_df = c2_class_df
        c2.ncounts = len(c2_class_df)    
        
    def update_children_df(self, df):
        if not self.children:
            raise KeyError(f'Class {self.name} does not have subclasses. Use update_class_df instead')
        for child in self.children:
            if child.class_df is None:
                child.update_class_df(df)
        class_df = self.children[0].class_df
        for c2 in self.children[1:]:
            inters = class_df.index.intersection(c2.class_df.index)
            c2_class_df = c2.class_df.drop(inters)
            class_df = pd.concat([class_df, c2_class_df])
        self.class_df = class_df            
        self.ncounts = len(class_df)
            
    def update_class_df(self, df):
        if not self.matching_strings:
            raise KeyError(f'Class {self.name} does not have matching string pattern to extract patients')
        class_df = df[df['ecg_rest_text'].str.count(self.matching_strings[0]) > 0.5]
        for matching_string in self.matching_strings[1:]:
            df2 = df[df['ecg_rest_text'].str.count(matching_string) > 0.5]
            inters = class_df.index.intersection(df2.index)
            df2 = df2.drop(inters)
            class_df = pd.concat([class_df, df2])
        self.class_df = class_df
        self.ncounts = len(class_df)  
        
    def hierarchical_tuples(self, tuples=None):        
        if tuples is None:
            tuples = []        
        for k, v in self.items():            
            if isinstance(v, ecg_class):
                v.hierarchical_tuples(tuples)            
        if len(self.children) == 0:
            tuples.append(self.class_parents + [self.id])
        return tuples
    
    def augment_df(self, df):
        hierarchical_tuples = self.hierarchical_tuples()
        old_tuples = [[old_col] for old_col in df]
        new_cols = pd.MultiIndex.from_tuples(hierarchical_tuples+old_tuples)
        new_df = pd.DataFrame(index=df.index, columns=new_cols)
        for new_col in new_cols: 
            if new_col[0] in df:
                new_df[new_col][:] = df[new_col[0]]
            else:
                this_class = self
                for l, level in enumerate(new_col):
                    if l == 0:
                        continue
                    if str(level) == 'nan':
                        break
                    this_class = this_class[level]
                new_df[new_col][:] = False
                if this_class.class_df is not None:
                    new_df[new_col].iloc[this_class.class_df.index] = True
        return new_df

# %%
classification = ecg_class('class', 'Classification')

# %%
rhythm = ecg_class('rhythm', 'Rhythm')
classification.add_child(rhythm)

# %%
sinus_rhythm = ecg_class('sinus_rhythm', 'Sinus rhythm')
classification['rhythm'].add_child(sinus_rhythm)
sinus_rhythm_no_arr = ecg_class('no_arr', 'Sinus rhythm no arrhythmia')
sinus_rhythm_yes_arr = ecg_class('yes_arr', 'Sinus rhythm with arrhythmia')
classification['rhythm']['sinus_rhythm'].add_child(sinus_rhythm_no_arr)
classification['rhythm']['sinus_rhythm'].add_child(sinus_rhythm_yes_arr)
classification['rhythm']['sinus_rhythm']['no_arr'].add_matching_string(r'[sS]inus rhythm')
classification['rhythm']['sinus_rhythm']['yes_arr'].add_matching_string(r'[sS]inus bradycardia')
classification['rhythm']['sinus_rhythm']['yes_arr'].add_matching_string(r'[sS]inus tachycardia')
classification['rhythm']['sinus_rhythm']['yes_arr'].add_matching_string(r'[sS]inus arrhythmia')
classification['rhythm']['sinus_rhythm'].make_children_exclusive(df)
print(classification['rhythm']['sinus_rhythm']['yes_arr'])
print(classification['rhythm']['sinus_rhythm']['no_arr'])
# Out:
#          |_____Sinus rhythm with arrhythmia: 16836 (44.75%)
#          |_____Sinus rhythm no arrhythmia: 19892 (52.87%)

# %%
ectopic_atrial = ecg_class('ectopic_atrial', 'Ectopic atrial rhythm')
classification['rhythm'].add_child(ectopic_atrial)
classification['rhythm']['ectopic_atrial'].add_matching_string(r'[Ee]ctopic atrial')
classification['rhythm']['ectopic_atrial'].add_matching_string(r'[Uu]nusual P axis possible ectopic atrial tachycardia')
classification['rhythm']['ectopic_atrial'].add_matching_string(r'[Uu]nusual P axis')
classification['rhythm']['ectopic_atrial'].update_class_df(df)
print(classification['rhythm']['ectopic_atrial'])
# Out:
#       |_____Ectopic atrial rhythm: 36 (0.10%)

# %%
atrial_fibrillation = ecg_class('atrial_fibrillation', 'Atrial fibrillation')
classification['rhythm'].add_child(atrial_fibrillation)
classification['rhythm']['atrial_fibrillation'].add_matching_string(r'Atrial fibrillation')
classification['rhythm']['atrial_fibrillation'].update_class_df(df)
print(classification['rhythm']['atrial_fibrillation'])
# Out:
#       |_____Atrial fibrillation: 512 (1.36%)

# %%
atrial_flutter = ecg_class('atrial_flutter', 'Atrial flutter')
classification['rhythm'].add_child(atrial_flutter)
atrial_flutter_fixed = ecg_class('fixed', 'Atrial flutter with fixed block')
atrial_flutter_variable = ecg_class('variable', 'Atrial flutter with variable block')
atrial_flutter_unspec = ecg_class('unspec', 'Atrial flutter with unspecified block')
classification['rhythm']['atrial_flutter'].add_child(atrial_flutter_fixed)
classification['rhythm']['atrial_flutter'].add_child(atrial_flutter_variable)
classification['rhythm']['atrial_flutter'].add_child(atrial_flutter_unspec)
classification['rhythm']['atrial_flutter']['fixed'].add_matching_string(r'[aA]trial flutter with [0-9]:1 AV conduction')
classification['rhythm']['atrial_flutter']['variable'].add_matching_string(r'[aA]trial flutter with variable AV block')
classification['rhythm']['atrial_flutter']['unspec'].add_matching_string('r[aA]trial flutter')
classification['rhythm']['atrial_flutter'].make_children_exclusive(df)
print(classification['rhythm']['atrial_flutter'])
print(classification['rhythm']['atrial_flutter']['fixed'])
print(classification['rhythm']['atrial_flutter']['variable'])
print(classification['rhythm']['atrial_flutter']['unspec'])
# Out:
#       |_____Atrial flutter: 28 (0.07%)
#          |_____Atrial flutter with fixed block: 10 (0.03%)
#          |_____Atrial flutter with variable block: 18 (0.05%)
#          |_____Atrial flutter with unspecified block: 0 (0.00%)

# %%
undetermined_rhythm = ecg_class('undetermined', 'Undetermined rhythm')
classification['rhythm'].add_child(undetermined_rhythm)
classification['rhythm']['undetermined'].add_matching_string('Undetermined rhythm')
classification['rhythm']['undetermined'].update_class_df(df)
print(classification['rhythm']['undetermined'])
# Out:
#       |_____Undetermined rhythm: 135 (0.36%)

# %%
junctional = ecg_class('junctional_rhythm', 'Junctional Rhythm')
classification.add_child(junctional)
classification['junctional_rhythm'].add_matching_string(r'[jJ]unctional rhythm')
classification['junctional_rhythm'].add_matching_string(r'[jJ]unctional pacemaker')
classification['junctional_rhythm'].add_matching_string(r'[jJ]unctional bradycardia')
classification['junctional_rhythm'].add_matching_string(r'[jJ]unctional escape complexes')
classification['junctional_rhythm'].update_class_df(df)
print(classification['junctional_rhythm'])
# Out:
#    |_____Junctional Rhythm: 173 (0.46%)

# %%
ventricular = ecg_class('ventricular_rhythm', 'Ventricular Rhythm')
classification.add_child(ventricular)
classification['ventricular_rhythm'].add_matching_string(r'[vV]entricular escape complexes')
classification['ventricular_rhythm'].update_class_df(df)
print(classification['ventricular_rhythm'])
# Out:
#    |_____Ventricular Rhythm: 23 (0.06%)

# %%
av_block = ecg_class('av_block', 'AV Block')
classification.add_child(av_block)
first_deg_block = ecg_class('first_deg', '1st degree AV Block')
second_deg_block = ecg_class('second_deg', '2nd degree AV Block')
third_deg_block = ecg_class('third_deg', '3rd degree AV Block')
dissoc_block = ecg_class('dissociation', 'AV dissociation')
classification['av_block'].add_child(first_deg_block)
classification['av_block']['first_deg'].add_matching_string('1st degree AV block')
classification['av_block'].add_child(second_deg_block)
classification['av_block']['second_deg'].add_matching_string('2nd degree AV block')
mobitz_I  = ecg_class('mobitz_I', '2nd degree AV block (Mobitz I)')
mobitz_II = ecg_class('mobitz_II', '2nd degree AV block (Mobitz II)')
unspec_av_block = ecg_class('unspecified', '2nd degree AV block (unspecified)')
classification['av_block']['second_deg'].add_child(mobitz_I)
classification['av_block']['second_deg'].add_child(mobitz_II)
classification['av_block']['second_deg'].add_child(unspec_av_block)
classification['av_block']['second_deg']['mobitz_I'].add_matching_string('Mobitz I')
classification['av_block']['second_deg']['mobitz_II'].add_matching_string('Mobitz II')
classification['av_block']['second_deg']['unspecified'].add_matching_string('2nd degree AV block')
classification['av_block'].add_child(third_deg_block)
classification['av_block']['third_deg'].add_matching_string('3rd degree AV block')
classification['av_block'].add_child(dissoc_block)
classification['av_block']['dissociation'].add_matching_string('AV dissociation')
classification['av_block']['second_deg'].make_children_exclusive(df)
classification['av_block'].make_children_exclusive(df)
print(classification['av_block'])
print(classification['av_block']['first_deg'])
print(classification['av_block']['second_deg'])
print(classification['av_block']['second_deg']['mobitz_I'])
print(classification['av_block']['second_deg']['mobitz_II'])
print(classification['av_block']['second_deg']['unspecified'])
print(classification['av_block']['third_deg'])
print(classification['av_block']['dissociation'])
# Out:
#    |_____AV Block: 2011 (5.35%)
#       |_____1st degree AV Block: 1991 (5.29%)
#       |_____2nd degree AV Block: 8 (0.02%)
#          |_____2nd degree AV block (Mobitz I): 5 (0.01%)
#          |_____2nd degree AV block (Mobitz II): 0 (0.00%)
#          |_____2nd degree AV block (unspecified): 3 (0.01%)
#       |_____3rd degree AV Block: 0 (0.00%)
#       |_____AV dissociation: 12 (0.03%)

# %%
# Subclasses of BBB can all occur at the same time
bbb = ecg_class('bbb', 'Bundle branch block')
classification.add_child(bbb)
bbb_left = ecg_class('left', 'Left bundle branch block')
bbb_right = ecg_class('right', 'Right bundle branch block')
bbb_ivcd = ecg_class('ivcd', 'Intraventricular conduction delay')
bbb_la_fascicular = ecg_class('la_fascicular', 'Left anterior fascicular block')
bbb_lp_fascicular = ecg_class('lp_fascicular', 'Left posterior fascicular block')
classification['bbb'].add_child(bbb_left)
classification['bbb'].add_child(bbb_right)
classification['bbb'].add_child(bbb_ivcd)
classification['bbb'].add_child(bbb_la_fascicular)
classification['bbb'].add_child(bbb_lp_fascicular)
classification['bbb']['ivcd'].add_matching_string(r'intraventricular block')
classification['bbb']['ivcd'].add_matching_string(r'intraventricular conduction delay')
classification['bbb']['la_fascicular'].add_matching_string(r'[lL]eft anterior fascicular block')
classification['bbb']['lp_fascicular'].add_matching_string(r'[lL]eft posterior fascicular block')
classification['bbb']['right'].add_matching_string(r'[rR]ight bundle branch block')
bbb_left_complete = ecg_class('complete', 'Complete left bundle branch block')
bbb_left_incomplete = ecg_class('incomplete', 'Incomplete left bundle branch block')
bbb_right_complete = ecg_class('complete', 'Complete right bundle branch block')
bbb_right_incomplete = ecg_class('incomplete', 'Incomplete right bundle branch block')
classification['bbb']['left'].add_child(bbb_left_incomplete)
classification['bbb']['left'].add_child(bbb_left_complete)
classification['bbb']['right'].add_child(bbb_right_complete)
classification['bbb']['right'].add_child(bbb_right_incomplete)
classification['bbb']['left']['incomplete'].add_matching_string(r'[Ii]ncomplete left bundle branch block')
classification['bbb']['left']['complete'].add_matching_string(r'Left bundle branch block')
classification['bbb']['right']['incomplete'].add_matching_string(r'[Ii]ncomplete right bundle branch block')
classification['bbb']['right']['complete'].add_matching_string(r'Right bundle branch block')
classification['bbb']['left'].make_children_exclusive(df)
classification['bbb']['right'].make_children_exclusive(df)
classification['bbb'].update_children_df(df)
print(classification['bbb'])
print(classification['bbb']['left'])
print(classification['bbb']['left']['complete'])
print(classification['bbb']['left']['incomplete'])
print(classification['bbb']['la_fascicular'])
print(classification['bbb']['lp_fascicular'])
print(classification['bbb']['right'])
print(classification['bbb']['right']['complete'])
print(classification['bbb']['right']['incomplete'])
print(classification['bbb']['ivcd'])
# Out:
#    |_____Bundle branch block: 3104 (8.25%)
#       |_____Left bundle branch block: 354 (0.94%)
#          |_____Complete left bundle branch block: 324 (0.86%)
#          |_____Incomplete left bundle branch block: 30 (0.08%)
#       |_____Left anterior fascicular block: 515 (1.37%)
#       |_____Left posterior fascicular block: 388 (1.03%)
#       |_____Right bundle branch block: 1794 (4.77%)
#          |_____Complete right bundle branch block: 728 (1.93%)
#          |_____Incomplete right bundle branch block: 1066 (2.83%)
#       |_____Intraventricular conduction delay: 227 (0.60%)

# %%
ectopy = ecg_class('ectopy', 'Ectopy')
classification.add_child(ectopy)
ectopy_pacs = ecg_class('pacs', 'Premature atrial complexes')
ectopy_pvcs = ecg_class('pvcs', 'Premature ventricular complexes')
classification['ectopy'].add_child(ectopy_pacs)
classification['ectopy'].add_child(ectopy_pvcs)
ectopy_pacs_isolated = ecg_class('isolated', 'Isolated premature atrial contractions')
ectopy_pacs_bigeminy = ecg_class('atrial_bigeminy', 'Atrial bigeminy')
ectopy_pacs_trigeminy = ecg_class('atrial_trigeminy', 'Atrial trigeminy')
classification['ectopy']['pacs'].add_child(ectopy_pacs_bigeminy)
classification['ectopy']['pacs'].add_child(ectopy_pacs_trigeminy)
classification['ectopy']['pacs'].add_child(ectopy_pacs_isolated)
classification['ectopy']['pacs']['atrial_bigeminy'].add_matching_string(r'atrial complexes in a pattern of bigeminy')
classification['ectopy']['pacs']['atrial_trigeminy'].add_matching_string(r'atrial complexes in a pattern of trigeminy')
classification['ectopy']['pacs']['isolated'].add_matching_string(r'[pP]remature atrial complexes')
classification['ectopy']['pacs'].make_children_exclusive(df)
ectopy_pvcs_isolated = ecg_class('isolated', 'Isolated premature ventricular contractions')
ectopy_pvcs_bigeminy = ecg_class('ventricular_bigeminy', 'Ventricular bigeminy')
ectopy_pvcs_trigeminy = ecg_class('ventricular_trigeminy', 'Ventricular trigeminy')
classification['ectopy']['pvcs'].add_child(ectopy_pvcs_bigeminy)
classification['ectopy']['pvcs'].add_child(ectopy_pvcs_trigeminy)
classification['ectopy']['pvcs'].add_child(ectopy_pvcs_isolated)
classification['ectopy']['pvcs']['ventricular_bigeminy'].add_matching_string(r'ventricular complexes in a pattern of bigeminy')
classification['ectopy']['pvcs']['ventricular_trigeminy'].add_matching_string(r'ventricular complexes in a pattern of trigeminy')
classification['ectopy']['pvcs']['isolated'].add_matching_string(r'[pP]remature ventricular complexes')
classification['ectopy']['pvcs'].make_children_exclusive(df)
classification['ectopy'].update_children_df(df)
print(classification['ectopy'])
print(classification['ectopy']['pacs'])
print(classification['ectopy']['pacs']['atrial_bigeminy'])
print(classification['ectopy']['pacs']['atrial_trigeminy'])
print(classification['ectopy']['pacs']['isolated'])
print(classification['ectopy']['pvcs'])
print(classification['ectopy']['pvcs']['ventricular_bigeminy'])
print(classification['ectopy']['pvcs']['ventricular_trigeminy'])
print(classification['ectopy']['pvcs']['isolated'])
# Out:
#    |_____Ectopy: 1812 (4.82%)
#       |_____Premature atrial complexes: 738 (1.96%)
#          |_____Atrial bigeminy: 15 (0.04%)
#          |_____Atrial trigeminy: 0 (0.00%)
#          |_____Isolated premature atrial contractions: 723 (1.92%)
#       |_____Premature ventricular complexes: 1095 (2.91%)
#          |_____Ventricular bigeminy: 17 (0.05%)
#          |_____Ventricular trigeminy: 0 (0.00%)
#          |_____Isolated premature ventricular contractions: 1078 (2.87%)

# %%
# Structural morphologies
structural = ecg_class('structural', 'Structural morphologies')
classification.add_child(structural)
lae = ecg_class('lae', 'Left atrial enlargement')
rae = ecg_class('rae', 'Right atrial enlargement')
classification['structural'].add_child(lae)
classification['structural'].add_child(rae)
classification['structural']['lae'].add_matching_string('[lL]eft atrial enlargement')
classification['structural']['lae'].add_matching_string('[bB]iatrial enlargement')
classification['structural']['rae'].add_matching_string('[rR]ight atrial enlargement')
classification['structural']['rae'].add_matching_string('[bB]iatrial enlargement')
old_infarct = ecg_class('old_infarct', 'Old myocardial infarct')
classification['structural'].add_child(old_infarct)
old_infarct_septal = ecg_class('septal', 'Old myocardial infarct (septal)')
old_infarct_anterior = ecg_class('anterior', 'Old myocardial infarct (anterior)')
old_infarct_inferior = ecg_class('inferior', 'Old myocardial infarct (inferior)')
old_infarct_lateral = ecg_class('lateral', 'Old myocardial infarct (lateral)')
old_infarct_posterior = ecg_class('posterior', 'Old myocardial infarct (posterior)')
old_infarct_unspec = ecg_class('unspec', 'Old myocardial infarct')
classification['structural']['old_infarct'].add_child(old_infarct_septal)
classification['structural']['old_infarct'].add_child(old_infarct_anterior)
classification['structural']['old_infarct'].add_child(old_infarct_inferior)
classification['structural']['old_infarct'].add_child(old_infarct_lateral)
classification['structural']['old_infarct'].add_child(old_infarct_posterior)
classification['structural']['old_infarct'].add_child(old_infarct_unspec)
classification['structural']['old_infarct']['septal'].add_matching_string('[sS]eptal infarct age undetermined')
classification['structural']['old_infarct']['septal'].add_matching_string('[aA]nteroseptal infarct age undetermined')
classification['structural']['old_infarct']['anterior'].add_matching_string('[sA]nterior infarct age undetermined')
classification['structural']['old_infarct']['anterior'].add_matching_string('[sA]nteroseptal infarct age undetermined')
classification['structural']['old_infarct']['anterior'].add_matching_string('[sA]nterolateral infarct age undetermined')
classification['structural']['old_infarct']['inferior'].add_matching_string('[iI]nferior infarct age undetermined')
classification['structural']['old_infarct']['inferior'].add_matching_string('[iI]nferior-posterior infarct age undetermined')
classification['structural']['old_infarct']['posterior'].add_matching_string('[iI]nferior-posterior infarct age undetermined')
classification['structural']['old_infarct']['posterior'].add_matching_string('[pP]osterior infarct age undetermined')
classification['structural']['old_infarct']['lateral'].add_matching_string('[sA]nterolateral infarct age undetermined')
classification['structural']['old_infarct']['lateral'].add_matching_string('[lL]ateral infarct age undetermined')
classification['structural']['old_infarct']['unspec'].add_matching_string('[iI]nfarct age undetermined')
classification['structural']['old_infarct'].update_children_df(df)
classification['structural']['old_infarct'].make_child_exclusive('unspec', df)
classification['structural'].update_children_df(df)
print(classification['structural']['lae'])
print(classification['structural']['rae'])
print(classification['structural']['old_infarct'])
print(classification['structural']['old_infarct']['septal'])
print(classification['structural']['old_infarct']['anterior'])
print(classification['structural']['old_infarct']['inferior'])
print(classification['structural']['old_infarct']['posterior'])
print(classification['structural']['old_infarct']['lateral'])
print(classification['structural']['old_infarct']['unspec'])
# Out:
#       |_____Left atrial enlargement: 2340 (6.22%)
#       |_____Right atrial enlargement: 90 (0.24%)
#       |_____Old myocardial infarct: 4515 (12.00%)
#          |_____Old myocardial infarct (septal): 960 (2.55%)
#          |_____Old myocardial infarct (anterior): 1878 (4.99%)
#          |_____Old myocardial infarct (inferior): 1470 (3.91%)
#          |_____Old myocardial infarct (posterior): 34 (0.09%)
#          |_____Old myocardial infarct (lateral): 695 (1.85%)
#          |_____Old myocardial infarct: 0 (0.00%)

# %%
acute_infarct = ecg_class('acute_infarct', 'Acute myocardial infarct')
classification['structural'].add_child(acute_infarct)
acute_infarct_septal = ecg_class('septal', 'Acute myocardial infarct (septal)')
acute_infarct_anterior = ecg_class('anterior', 'Acute myocardial infarct (anterior)')
acute_infarct_inferior = ecg_class('inferior', 'Acute myocardial infarct (inferior)')
acute_infarct_lateral = ecg_class('lateral', 'Acute myocardial infarct (lateral)')
acute_infarct_posterior = ecg_class('posterior', 'Acute myocardial infarct (posterior)')
acute_infarct_unspec = ecg_class('unspec', 'Acute myocardial infarct')
classification['structural']['acute_infarct'].add_child(acute_infarct_septal)
classification['structural']['acute_infarct'].add_child(acute_infarct_anterior)
classification['structural']['acute_infarct'].add_child(acute_infarct_inferior)
classification['structural']['acute_infarct'].add_child(acute_infarct_lateral)
classification['structural']['acute_infarct'].add_child(acute_infarct_posterior)
classification['structural']['acute_infarct'].add_child(acute_infarct_unspec)
classification['structural']['acute_infarct']['septal'].add_matching_string('[sS]eptal infarct possibly acute')
classification['structural']['acute_infarct']['septal'].add_matching_string('[sS]eptal injury pattern')
classification['structural']['acute_infarct']['septal'].add_matching_string('[aA]nteroseptal infarct possibly acute')
classification['structural']['acute_infarct']['anterior'].add_matching_string('ST elevation consider anterior injury or acute infarct')
classification['structural']['acute_infarct']['anterior'].add_matching_string('ST elevation consider anterolateral injury or acute infarct')
classification['structural']['acute_infarct']['anterior'].add_matching_string('[aA]nterior injury pattern')
classification['structural']['acute_infarct']['anterior'].add_matching_string('[aA]nterior infarct possibly acute')
classification['structural']['acute_infarct']['anterior'].add_matching_string('[Aa]nteroseptal infarct possibly acute')
classification['structural']['acute_infarct']['inferior'].add_matching_string('ST elevation consider inferior injury or acute infarct')
classification['structural']['acute_infarct']['inferior'].add_matching_string('ST elevation consider inferolateral injury or acute infarct')
classification['structural']['acute_infarct']['inferior'].add_matching_string('[aA]cute inferior infarct')
classification['structural']['acute_infarct']['inferior'].add_matching_string('[iI]nferior injury pattern')
classification['structural']['acute_infarct']['inferior'].add_matching_string('[iI]nferior infarct possibly acute')
classification['structural']['acute_infarct']['inferior'].add_matching_string('[iI]nferior-posterior infarct possibly acute')
classification['structural']['acute_infarct']['posterior'].add_matching_string('[pP]osterior injury pattern')
classification['structural']['acute_infarct']['posterior'].add_matching_string('[pP]osterior infarct possibly acute')
classification['structural']['acute_infarct']['posterior'].add_matching_string('[iI]nferior-posterior infarct possibly acute')
classification['structural']['acute_infarct']['lateral'].add_matching_string('[lL]ateral injury pattern')
classification['structural']['acute_infarct']['lateral'].add_matching_string('[lL]ateral infarct possibly acute')
classification['structural']['acute_infarct']['lateral'].add_matching_string('ST elevation consider lateral injury or acute infarct')
classification['structural']['acute_infarct']['lateral'].add_matching_string('ST elevation consider inferolateral injury or acute infarct')
classification['structural']['acute_infarct']['lateral'].add_matching_string('ST elevation consider anterolateral injury or acute infarct')
classification['structural']['acute_infarct']['lateral'].add_matching_string('[sA]nterolateral infarct possibly acute')
classification['structural']['acute_infarct']['lateral'].add_matching_string('[lL]ateral infarct age possibly acute')
classification['structural']['acute_infarct']['unspec'].add_matching_string('[aA][cC][uU][tT][eE] [mM][iI]')
classification['structural']['acute_infarct'].update_children_df(df)
classification['structural']['acute_infarct'].make_child_exclusive('unspec', df)
classification['structural'].update_children_df(df)
print(classification['structural']['acute_infarct'])
print(classification['structural']['acute_infarct']['septal'])
print(classification['structural']['acute_infarct']['anterior'])
print(classification['structural']['acute_infarct']['inferior'])
print(classification['structural']['acute_infarct']['posterior'])
print(classification['structural']['acute_infarct']['lateral'])
print(classification['structural']['acute_infarct']['unspec'])
# Out:
#       |_____Acute myocardial infarct: 159 (0.42%)
#          |_____Acute myocardial infarct (septal): 8 (0.02%)
#          |_____Acute myocardial infarct (anterior): 40 (0.11%)
#          |_____Acute myocardial infarct (inferior): 76 (0.20%)
#          |_____Acute myocardial infarct (posterior): 1 (0.00%)
#          |_____Acute myocardial infarct (lateral): 51 (0.14%)
#          |_____Acute myocardial infarct: 0 (0.00%)

# %%
st_depression = ecg_class('st_depression', 'ST Depression')
classification['structural'].add_child(st_depression)
st_depression_unspec = ecg_class('unspec', 'Unspecified ST depression')
classification['structural']['st_depression'].add_child(st_depression_unspec)
classification['structural']['st_depression']['unspec'].add_matching_string('ST depression probably abnormal')
classification['structural']['st_depression']['unspec'].add_matching_string('ST depression probably normal')
classification['structural']['st_depression'].update_children_df(df)
print(classification['structural']['st_depression'])
print(classification['structural']['st_depression']['unspec'])
# Out:
#       |_____ST Depression: 409 (1.09%)
#          |_____Unspecified ST depression: 409 (1.09%)

# %%
st_abnormal = ecg_class('st_abnormality', 'ST segment abnormality')
classification['structural'].add_child(st_abnormal)
st_abnormal_septal = ecg_class('septal', 'ST abnormality localized septally')
st_abnormal_lateral = ecg_class('lateral', 'ST abnormality localized laterally')
st_abnormal_inferior = ecg_class('inferior', 'ST abnormality localized inferiorly')
st_abnormal_anterior = ecg_class('anterior', 'ST abnormality localized anteriorly')
st_abnormal_posterior = ecg_class('posterior', 'ST abnormality localized posteriorly')
st_abnormal_unspec = ecg_class('unspec', 'Unspecified ST segment abnormality')
classification['structural']['st_abnormality'].add_child(st_abnormal_septal)
classification['structural']['st_abnormality'].add_child(st_abnormal_lateral)
classification['structural']['st_abnormality'].add_child(st_abnormal_inferior)
classification['structural']['st_abnormality'].add_child(st_abnormal_anterior)
classification['structural']['st_abnormality'].add_child(st_abnormal_posterior)
classification['structural']['st_abnormality'].add_child(st_abnormal_unspec)
classification['structural']['st_abnormality']['septal'].add_matching_string('ST abnormality consider septal ischemia')
classification['structural']['st_abnormality']['septal'].add_matching_string('ST and T wave abnormality consider septal ischemia')
classification['structural']['st_abnormality']['lateral'].add_matching_string('ST abnormality consider lateral ischemia')
classification['structural']['st_abnormality']['lateral'].add_matching_string('ST abnormality consider anterolateral ischemia')
classification['structural']['st_abnormality']['lateral'].add_matching_string('ST abnormality consider inferolateral ischemia')
classification['structural']['st_abnormality']['lateral'].add_matching_string('ST and T wave abnormality consider lateral ischemia')
classification['structural']['st_abnormality']['lateral'].add_matching_string('ST and T wave abnormality consider anterolateral ischemia')
classification['structural']['st_abnormality']['lateral'].add_matching_string('ST and T wave abnormality consider inferolateral ischemia')
classification['structural']['st_abnormality']['inferior'].add_matching_string('ST abnormality consider inferior ischemia')
classification['structural']['st_abnormality']['inferior'].add_matching_string('ST abnormality consider inferolateral ischemia')
classification['structural']['st_abnormality']['inferior'].add_matching_string('ST and T wave abnormality consider inferior ischemia')
classification['structural']['st_abnormality']['inferior'].add_matching_string('ST and T wave abnormality consider inferolateral ischemia')
classification['structural']['st_abnormality']['anterior'].add_matching_string('ST abnormality consider anterior ischemia')
classification['structural']['st_abnormality']['anterior'].add_matching_string('ST abnormality consider anterolateral ischemia')
classification['structural']['st_abnormality']['anterior'].add_matching_string('ST and T wave abnormality consider anterior ischemia')
classification['structural']['st_abnormality']['anterior'].add_matching_string('ST and T wave abnormality consider anterolateral ischemia')
classification['structural']['st_abnormality']['posterior'].add_matching_string('ST abnormality consider posterior ischemia')
classification['structural']['st_abnormality']['posterior'].add_matching_string('ST and T wave abnormality consider posterior ischemia')
classification['structural']['st_abnormality']['unspec'].add_matching_string('ST and T wave abnormality')
classification['structural']['st_abnormality']['unspec'].add_matching_string('ST abnormality')
classification['structural']['st_abnormality'].update_children_df(df)
classification['structural']['st_abnormality'].make_child_exclusive('unspec', df)
print(classification['structural']['st_abnormality'])
print(classification['structural']['st_abnormality']['septal'])
print(classification['structural']['st_abnormality']['lateral'])
print(classification['structural']['st_abnormality']['inferior'])
print(classification['structural']['st_abnormality']['anterior'])
print(classification['structural']['st_abnormality']['posterior'])
print(classification['structural']['st_abnormality']['unspec'])
# Out:
#       |_____ST segment abnormality: 2921 (7.76%)
#          |_____ST abnormality localized septally: 0 (0.00%)
#          |_____ST abnormality localized laterally: 214 (0.57%)
#          |_____ST abnormality localized inferiorly: 154 (0.41%)
#          |_____ST abnormality localized anteriorly: 153 (0.41%)
#          |_____ST abnormality localized posteriorly: 0 (0.00%)
#          |_____Unspecified ST segment abnormality: 2484 (6.60%)

# %%
tw_abnormal = ecg_class('tw_abnormality', 'T wave abnormality')
classification['structural'].add_child(tw_abnormal)
tw_abnormal_septal = ecg_class('septal', 'T wave abnormality localized septally')
tw_abnormal_lateral = ecg_class('lateral', 'T wave abnormality localized laterally')
tw_abnormal_inferior = ecg_class('inferior', 'T wave abnormality localized inferiorly')
tw_abnormal_anterior = ecg_class('anterior', 'T wave abnormality localized anteriorly')
tw_abnormal_posterior = ecg_class('posterior', 'T wave abnormality localized posteriorly')
tw_abnormal_unspec = ecg_class('unspec', 'Unspecified T wave segment abnormality')
classification['structural']['tw_abnormality'].add_child(tw_abnormal_septal)
classification['structural']['tw_abnormality'].add_child(tw_abnormal_lateral)
classification['structural']['tw_abnormality'].add_child(tw_abnormal_inferior)
classification['structural']['tw_abnormality'].add_child(tw_abnormal_anterior)
classification['structural']['tw_abnormality'].add_child(tw_abnormal_posterior)
classification['structural']['tw_abnormality'].add_child(tw_abnormal_unspec)
classification['structural']['tw_abnormality']['septal'].add_matching_string('T wave abnormality consider septal ischemia')
classification['structural']['tw_abnormality']['septal'].add_matching_string('ST and T wave abnormality consider septal ischemia')
classification['structural']['tw_abnormality']['lateral'].add_matching_string('T wave abnormality consider lateral ischemia')
classification['structural']['tw_abnormality']['lateral'].add_matching_string('T wave abnormality consider anterolateral ischemia')
classification['structural']['tw_abnormality']['lateral'].add_matching_string('T wave abnormality consider inferolateral ischemia')
classification['structural']['tw_abnormality']['lateral'].add_matching_string('ST and T wave abnormality consider lateral ischemia')
classification['structural']['tw_abnormality']['lateral'].add_matching_string('ST and T wave abnormality consider anterolateral ischemia')
classification['structural']['tw_abnormality']['lateral'].add_matching_string('ST and T wave abnormality consider inferolateral ischemia')
classification['structural']['tw_abnormality']['inferior'].add_matching_string('T wave abnormality consider inferior ischemia')
classification['structural']['tw_abnormality']['inferior'].add_matching_string('T wave abnormality consider inferolateral ischemia')
classification['structural']['tw_abnormality']['inferior'].add_matching_string('ST and T wave abnormality consider inferior ischemia')
classification['structural']['tw_abnormality']['inferior'].add_matching_string('ST and T wave abnormality consider inferolateral ischemia')
classification['structural']['tw_abnormality']['anterior'].add_matching_string('T wave abnormality consider anterior ischemia')
classification['structural']['tw_abnormality']['anterior'].add_matching_string('T wave abnormality consider anterolateral ischemia')
classification['structural']['tw_abnormality']['anterior'].add_matching_string('ST and T wave abnormality consider anterior ischemia')
classification['structural']['tw_abnormality']['anterior'].add_matching_string('ST and T wave abnormality consider anterolateral ischemia')
classification['structural']['tw_abnormality']['posterior'].add_matching_string('T wave abnormality consider posterior ischemia')
classification['structural']['tw_abnormality']['posterior'].add_matching_string('ST and T wave abnormality consider posterior ischemia')
classification['structural']['tw_abnormality']['unspec'].add_matching_string('ST and T wave abnormality')
classification['structural']['tw_abnormality']['unspec'].add_matching_string('T wave abnormality')
classification['structural']['tw_abnormality'].update_children_df(df)
classification['structural']['tw_abnormality'].make_child_exclusive('unspec', df)
print(classification['structural']['tw_abnormality'])
print(classification['structural']['tw_abnormality']['septal'])
print(classification['structural']['tw_abnormality']['lateral'])
print(classification['structural']['tw_abnormality']['inferior'])
print(classification['structural']['tw_abnormality']['anterior'])
print(classification['structural']['tw_abnormality']['posterior'])
print(classification['structural']['tw_abnormality']['unspec'])
# Out:
#       |_____T wave abnormality: 3174 (8.44%)
#          |_____T wave abnormality localized septally: 0 (0.00%)
#          |_____T wave abnormality localized laterally: 441 (1.17%)
#          |_____T wave abnormality localized inferiorly: 303 (0.81%)
#          |_____T wave abnormality localized anteriorly: 309 (0.82%)
#          |_____T wave abnormality localized posteriorly: 0 (0.00%)
#          |_____Unspecified T wave segment abnormality: 2267 (6.03%)

# %%
st_elevation = ecg_class('st_elevation', 'ST elevation')
classification['structural'].add_child(st_elevation)
classification['structural']['st_elevation'].add_matching_string('ST elevation')
classification['structural']['st_elevation'].update_class_df(df)
print(classification['structural']['st_elevation'])
# Out:
#       |_____ST elevation: 268 (0.71%)

# %%
lvh = ecg_class('lvh', 'Left ventricular hypertrophy')
rvh = ecg_class('rvh', 'Right ventricular hypertrophy')
classification['structural'].add_child(lvh)
classification['structural'].add_child(rvh)
classification['structural']['lvh'].add_matching_string('[Ll][Vv][Hh]')
classification['structural']['lvh'].add_matching_string('[Ll]eft ventricular hypertrophy')
classification['structural']['lvh'].update_class_df(df)
classification['structural']['rvh'].add_matching_string('[Rr][Vv][Hh]')
classification['structural']['rvh'].add_matching_string('[Rr]ight ventricular hypertrophy')
classification['structural']['rvh'].update_class_df(df)
print(classification['structural']['lvh'])
print(classification['structural']['rvh'])
# Out:
#       |_____Left ventricular hypertrophy: 2669 (7.09%)
#       |_____Right ventricular hypertrophy: 62 (0.16%)

# %%
early_rep = ecg_class('early_rep', 'Early repolarization')
classification['structural'].add_child(early_rep)
classification['structural']['early_rep'].add_matching_string('[eE]arly repolarization')
classification['structural']['early_rep'].update_class_df(df)
print(classification['structural']['early_rep'])
# Out:
#       |_____Early repolarization: 322 (0.86%)

# %%
brugada = ecg_class('brugada', 'Brugada pattern')
digitalis = ecg_class('digitalis', 'Digitalis effect')
pericarditis = ecg_class('pericarditis', 'Acute pericarditis')
classification['structural'].add_child(brugada)
classification['structural'].add_child(digitalis)
classification['structural'].add_child(pericarditis)
classification['structural']['brugada'].add_matching_string('brugada')
classification['structural']['digitalis'].add_matching_string('digitalis')
classification['structural']['pericarditis'].add_matching_string('[Aa]cute pericarditis')
classification['structural']['brugada'].update_class_df(df)
classification['structural']['digitalis'].update_class_df(df)
classification['structural']['pericarditis'].update_class_df(df)
print(classification['structural']['brugada'])
print(classification['structural']['digitalis'])
print(classification['structural']['pericarditis'])
# Out:
#       |_____Brugada pattern: 0 (0.00%)
#       |_____Digitalis effect: 523 (1.39%)
#       |_____Acute pericarditis: 1 (0.00%)

# %%
counterclockwise_rotation = ecg_class('counterclockwise', 'Counter clockwise rotation')
classification['structural'].add_child(counterclockwise_rotation)
classification['structural']['counterclockwise'].add_matching_string('early transition')
classification['structural']['counterclockwise'].update_class_df(df)
print(classification['structural']['counterclockwise'])
# Out:
#       |_____Counter clockwise rotation: 138 (0.37%)

# %%
pulmonary_disease = ecg_class('pulmonary', 'Pulmonary disease pattern')
ventricular_preexcitation = ecg_class('ventricular_preexcitation', 'Ventricular pre-excitation')
classification['structural'].add_child(pulmonary_disease)
classification['structural'].add_child(ventricular_preexcitation)
classification['structural']['pulmonary'].add_matching_string('[pP]ulmonary disease')
classification['structural']['ventricular_preexcitation'].add_matching_string('[vV]entricular pre-excitation')
classification['structural']['ventricular_preexcitation'].add_matching_string('Wolff-Parkinson-White')
classification['structural']['ventricular_preexcitation'].add_matching_string('WPW')
classification['structural']['pulmonary'].update_class_df(df)
classification['structural']['ventricular_preexcitation'].update_class_df(df)
print(classification['structural']['pulmonary'])
print(classification['structural']['ventricular_preexcitation'])
# Out:
#       |_____Pulmonary disease pattern: 110 (0.29%)
#       |_____Ventricular pre-excitation: 11 (0.03%)

# %%
classification.print_hierarchy()
# Out:
#    |_____Rhythm: 0 (0.00%)
#       |_____Sinus rhythm: 36728 (97.62%)
#          |_____Sinus rhythm no arrhythmia: 19892 (52.87%)
#          |_____Sinus rhythm with arrhythmia: 16836 (44.75%)
#       |_____Ectopic atrial rhythm: 36 (0.10%)
#       |_____Atrial fibrillation: 512 (1.36%)
#       |_____Atrial flutter: 28 (0.07%)
#          |_____Atrial flutter with fixed block: 10 (0.03%)
#          |_____Atrial flutter with variable block: 18 (0.05%)
#          |_____Atrial flutter with unspecified block: 0 (0.00%)
#       |_____Undetermined rhythm: 135 (0.36%)
#    |_____Junctional Rhythm: 173 (0.46%)
#    |_____Ventricular Rhythm: 23 (0.06%)
#    |_____AV Block: 2011 (5.35%)
#       |_____1st degree AV Block: 1991 (5.29%)
#       |_____2nd degree AV Block: 8 (0.02%)
#          |_____2nd degree AV block (Mobitz I): 5 (0.01%)
#          |_____2nd degree AV block (Mobitz II): 0 (0.00%)
#          |_____2nd degree AV block (unspecified): 3 (0.01%)
#       |_____3rd degree AV Block: 0 (0.00%)
#       |_____AV dissociation: 12 (0.03%)
#    |_____Bundle branch block: 3104 (8.25%)
#       |_____Left bundle branch block: 354 (0.94%)
#          |_____Incomplete left bundle branch block: 30 (0.08%)
#          |_____Complete left bundle branch block: 324 (0.86%)
#       |_____Right bundle branch block: 1794 (4.77%)
#          |_____Complete right bundle branch block: 728 (1.93%)
#          |_____Incomplete right bundle branch block: 1066 (2.83%)
#       |_____Intraventricular conduction delay: 227 (0.60%)
#       |_____Left anterior fascicular block: 515 (1.37%)
#       |_____Left posterior fascicular block: 388 (1.03%)
#    |_____Ectopy: 1812 (4.82%)
#       |_____Premature atrial complexes: 738 (1.96%)
#          |_____Atrial bigeminy: 15 (0.04%)
#          |_____Atrial trigeminy: 0 (0.00%)
#          |_____Isolated premature atrial contractions: 723 (1.92%)
#       |_____Premature ventricular complexes: 1095 (2.91%)
#          |_____Ventricular bigeminy: 17 (0.05%)
#          |_____Ventricular trigeminy: 0 (0.00%)
#          |_____Isolated premature ventricular contractions: 1078 (2.87%)
#    |_____Structural morphologies: 6737 (17.91%)
#       |_____Left atrial enlargement: 2340 (6.22%)
#       |_____Right atrial enlargement: 90 (0.24%)
#       |_____Old myocardial infarct: 4515 (12.00%)
#          |_____Old myocardial infarct (septal): 960 (2.55%)
#          |_____Old myocardial infarct (anterior): 1878 (4.99%)
#          |_____Old myocardial infarct (inferior): 1470 (3.91%)
#          |_____Old myocardial infarct (lateral): 695 (1.85%)
#          |_____Old myocardial infarct (posterior): 34 (0.09%)
#          |_____Old myocardial infarct: 0 (0.00%)
#       |_____Acute myocardial infarct: 159 (0.42%)
#          |_____Acute myocardial infarct (septal): 8 (0.02%)
#          |_____Acute myocardial infarct (anterior): 40 (0.11%)
#          |_____Acute myocardial infarct (inferior): 76 (0.20%)
#          |_____Acute myocardial infarct (lateral): 51 (0.14%)
#          |_____Acute myocardial infarct (posterior): 1 (0.00%)
#          |_____Acute myocardial infarct: 0 (0.00%)
#       |_____ST Depression: 409 (1.09%)
#          |_____Unspecified ST depression: 409 (1.09%)
#       |_____ST segment abnormality: 2921 (7.76%)
#          |_____ST abnormality localized septally: 0 (0.00%)
#          |_____ST abnormality localized laterally: 214 (0.57%)
#          |_____ST abnormality localized inferiorly: 154 (0.41%)
#          |_____ST abnormality localized anteriorly: 153 (0.41%)
#          |_____ST abnormality localized posteriorly: 0 (0.00%)
#          |_____Unspecified ST segment abnormality: 2484 (6.60%)
#       |_____T wave abnormality: 3174 (8.44%)
#          |_____T wave abnormality localized septally: 0 (0.00%)
#          |_____T wave abnormality localized laterally: 441 (1.17%)
#          |_____T wave abnormality localized inferiorly: 303 (0.81%)
#          |_____T wave abnormality localized anteriorly: 309 (0.82%)
#          |_____T wave abnormality localized posteriorly: 0 (0.00%)
#          |_____Unspecified T wave segment abnormality: 2267 (6.03%)
#       |_____ST elevation: 268 (0.71%)
#       |_____Left ventricular hypertrophy: 2669 (7.09%)
#       |_____Right ventricular hypertrophy: 62 (0.16%)
#       |_____Early repolarization: 322 (0.86%)
#       |_____Brugada pattern: 0 (0.00%)
#       |_____Digitalis effect: 523 (1.39%)
#       |_____Acute pericarditis: 1 (0.00%)
#       |_____Counter clockwise rotation: 138 (0.37%)
#       |_____Pulmonary disease pattern: 110 (0.29%)
#       |_____Ventricular pre-excitation: 11 (0.03%)

# %%
df2 = classification.augment_df(df)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df2['class']['rhythm']

# %%
new_cols = pd.MultiIndex.from_tuples(new_old_cols + tuples)

# %%
new_cols

# %%
new_old_cols = [[old_col, ] for old_col in df]

# %%
new_old_cols + tuples

# %%
def augment_df(self, df):
        hierarchical_tuples = self.hierarchical_tuples()
        old_tuples = [[old_col] for old_col in df]
        new_cols = pd.MultiIndex.from_tuples(hierarchical_tuples+old_tuples)
        new_df = pd.DataFrame(index=df.index, columns=new_cols, dtype=float)
        for new_col in new_cols:
            if new_col[0] in df:
                print(new_col)
                new_df[new_col][:] = df[new_col[0]]
            else:
                this_class = self
                for l, level in enumerate(new_col):
                    if l == 0:
                        continue
                    if str(level) == 'nan':
                        break
                    this_class = this_class[level]
                new_df[new_col][:] = False
                if this_class.class_df is not None:
                    new_df[new_col].iloc[this_class.class_df.index] = True
        return new_df

# %%
df2 = augment_df(classification, df)

# %%
df2
