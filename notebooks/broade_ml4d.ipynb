# %% [markdown]
# ### Welcome to ML4D BroadE!
# We explore machine learning on Bio medical data using Cloud computing, Python, Tensorflow, and the ML4CVD codebase.
#
# We will start with linear regression.  Our model is a vector, one weight for each input feature, and a single bias weight.
#
# \begin{equation}
# y = xw + b
# \end{equation}
#
# For notational convenience absorb the bias term into the weight vector by adding a 1 to the input data matrix X
#
# \begin{equation}
# y = [1, x][b, w]^T
# \end{equation}

# %%
import os
import h5py
import numpy as np
from typing import List, Dict, Callable
from collections import defaultdict, Counter

# Import:
import os
import sys
import gzip
import pickle
import random

import pydicom
import numpy as np


# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec

from keras import metrics
from keras.models import Sequential
from keras.layers.core import Dense

from ml4cvd.arguments import _get_tmap
from ml4cvd.TensorMap import TensorMap
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/apache_beam/__init__.py:84: UserWarning: Running the Apache Beam SDK on Python 3 is not yet fully supported. You may encounter buggy behavior or missing features.
#   'Running the Apache Beam SDK on Python 3 is not yet fully supported. '

# %%
def linear_regression():
    samples = 40
    real_weight = 2.0
    real_bias = 0.5
    x = np.linspace(-1, 1, samples)
    y = real_weight*x + real_bias + (np.random.randn(*x.shape) * 0.1)

    linear_model = Sequential()
    linear_model.add(Dense(1, input_dim=1))
    linear_model.compile(loss='mse', optimizer='sgd')
    linear_model.summary()
    linear_model.fit(x, y, batch_size=1, epochs=10)

    learned_slope = linear_model.get_weights()[0][0][0]
    learned_bias = linear_model.get_weights()[1][0]
    print('Learned slope:',  learned_slope, 'real slope:', real_weight, 'learned bias:', learned_bias, 'real bias:', real_bias)

    plt.plot(x, y)
    plt.plot([-1,1], [-learned_slope+learned_bias, learned_slope+learned_bias], 'r')
    plt.show()
    print('Linear Regression complete!')

# %%
linear_regression()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 40/40 [==============================] - 5s 115ms/step - loss: 1.0753
# Epoch 2/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5654
# Epoch 3/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3147
# Epoch 4/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1801
# Epoch 5/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1061
# Epoch 6/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0646
# Epoch 7/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0415
# Epoch 8/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0283
# Epoch 9/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0205
# Epoch 10/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0163
# Learned slope: 1.8866316 real slope: 2.0 learned bias: 0.49711087 real bias: 0.5
# Linear Regression complete!

# %% [markdown]
# ## Now Logistic Regression:
# We take the real-valued predictions from linear regression and squish them with a sigmoid.
#
# \begin{equation}
# \textbf{y} = \sigma(X\textbf{w} + b)
# \end{equation}
#
# where
# \begin{equation}
# \sigma(x) = \frac{e^x}{1+e^x} = \frac{1}{1+e^{-x}}
# \end{equation}

# %%
import math

def sigmoid(x):
    a = []
    for item in x:
        a.append(math.exp(item)/(1+math.exp(item)))
    return a

# %%
x = np.arange(-10., 10., 0.2)
sig = sigmoid(x)
plt.plot(x,sig)
plt.show()

# %%
def logistic_regression():
	train, test, valid = load_data('mnist.pkl.gz')

	epochs = 1000
	num_labels = 10
	train_y = make_one_hot(train[1], num_labels)
	valid_y = make_one_hot(valid[1], num_labels)
	test_y = make_one_hot(test[1], num_labels)

	logistic_model = Sequential()
	logistic_model.add(Dense(10, activation='softmax', input_dim=784, name='mnist_templates'))
	logistic_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
	logistic_model.summary()
	templates = logistic_model.layers[0].get_weights()[0]
	plot_templates(templates, 0)
	print('weights shape:', templates.shape)

	for e in range(epochs):
		trainidx = random.sample(range(0, train[0].shape[0]), 8192)
		x_batch = train[0][trainidx,:]
		y_batch = train_y[trainidx]
		logistic_model.train_on_batch(x_batch, y_batch)
		if e % 100 == 0:
			plot_templates(logistic_model.layers[0].get_weights()[0], e)
			print('Logistic Model test set loss and accuracy:', logistic_model.evaluate(test[0], test_y), 'at epoch', e)


def plot_templates(templates, epoch):
	n = 10
	templates = templates.reshape((28,28,n))
	plt.figure(figsize=(16, 8))
	for i in range(n):
		ax = plt.subplot(2, 5, i+1)		
		plt.imshow(templates[:, :, i])
		plt.gray()
		ax.get_xaxis().set_visible(False)
		ax.get_yaxis().set_visible(False)

	plot_name = "./regression_example/mnist_templates_"+str(epoch)+".png"
	if not os.path.exists(os.path.dirname(plot_name)):
		os.makedirs(os.path.dirname(plot_name))		
	plt.savefig(plot_name)


def make_one_hot(y, num_labels):
	ohy = np.zeros((len(y), num_labels))
	for i in range(0, len(y)):
		ohy[i][y[i]] = 1.0
	return ohy


def load_data(dataset):
	''' Loads the dataset
	:type dataset: string
	:param dataset: the path to the dataset (here MNIST)
	'''

	#############
	# LOAD DATA #
	#############

	# Download the MNIST dataset if it is not present
	data_dir, data_file = os.path.split(dataset)
	if data_dir == "" and not os.path.isfile(dataset):
		# Check if dataset is in the data directory.
		new_path = os.path.join("data", dataset)
		if os.path.isfile(new_path) or data_file == 'mnist.pkl.gz':
			dataset = new_path

	if (not os.path.isfile(dataset)) and data_file == 'mnist.pkl.gz':
		from urllib.request import urlretrieve
		origin = (
			'http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz'
		)
		print('Downloading data from %s' % origin)
		if not os.path.exists(os.path.dirname(dataset)):
			os.makedirs(os.path.dirname(dataset))	
		urlretrieve(origin, dataset)

	print('loading data...')

	# Load the dataset
	f = gzip.open(dataset, 'rb')
	if sys.version_info[0] == 3:
		u = pickle._Unpickler(f)
		u.encoding = 'latin1'
		train_set, valid_set, test_set = u.load()
	else:
		train_set, valid_set, test_set = pickle.load(f)

	f.close()
	#train_set, valid_set, test_set format: tuple(input, target)
	#input is an numpy.ndarray of 2 dimensions (a matrix)
	#which row's correspond to an example. target is a
	#numpy.ndarray of 1 dimensions (vector)) that have the same length as
	#the number of rows in the input. It should give the target
	#target to the example with the same index in the input.

	return train_set, valid_set, test_set

# %% [markdown]
# ## Cross Entropy Loss:
# Our favorite loss function for categorical data.
# \begin{equation}
# L(true, model) = -\sum_{x\in\mathcal{X}} true(x)\, \log model(x)
# \end{equation}
#
# Binary cross entropy with $N$ data points $x$ each with a binary label:
# \begin{equation}
# true(x) \in \{0, 1\} \\
# L(true, model) = -\frac{1}{N}\sum^N_{i=1} true(x_i)\log(model(x_i)) + (1-true(x_i))log(1-model(x_i))
# \end{equation}
#
# This is the Kullback Leibler divergence between the true distribution and the predicted.
# This function emerges in many fields as diverse as probability, information theory, and physics.
# What is the information difference between the truth and our model?  How much data do I lose by replacing the truth with the model's predictions. What is the temperature difference between my predictions and the truth?!
#
# Categorical cross entropy with $K$ different classes or labels:
# \begin{equation}
# true(x) \in \{0, 1, 2, ..., K\} \\
# L(true, model) = -\frac{1}{N}\sum^N_{i=1}\sum^K_{j=1} y_{ik}\log(q_k(x_i)))
# \end{equation}

# %%
logistic_regression()
# Out:
# Downloading data from http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz
# loading data...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mnist_templates (Dense)      (None, 10)                7850
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________
# weights shape: (784, 10)
# 10000/10000 [==============================] - 0s 42us/step
# Logistic Model test set loss and accuracy: [2.483477196121216, 0.0772] at epoch 0
# 10000/10000 [==============================] - 0s 38us/step
# Logistic Model test set loss and accuracy: [1.6379679027557372, 0.6589] at epoch 100
# 10000/10000 [==============================] - 0s 38us/step
# Logistic Model test set loss and accuracy: [1.2253220737457275, 0.7852] at epoch 200
# 10000/10000 [==============================] - 0s 38us/step
# Logistic Model test set loss and accuracy: [1.0026916637420655, 0.8216] at epoch 300
# 10000/10000 [==============================] - 0s 38us/step
# Logistic Model test set loss and accuracy: [0.8679577152252197, 0.8405] at epoch 400
# 10000/10000 [==============================] - 0s 37us/step
# Logistic Model test set loss and accuracy: [0.778641467666626, 0.849] at epoch 500
# 10000/10000 [==============================] - 0s 38us/step
# Logistic Model test set loss and accuracy: [0.7150067184448242, 0.8547] at epoch 600
# 10000/10000 [==============================] - 0s 38us/step
# Logistic Model test set loss and accuracy: [0.6671992763519287, 0.8609] at epoch 700
# 10000/10000 [==============================] - 0s 38us/step
# Logistic Model test set loss and accuracy: [0.6298645363330841, 0.8655] at epoch 800
# 10000/10000 [==============================] - 0s 38us/step
# Logistic Model test set loss and accuracy: [0.5999010292053223, 0.8686] at epoch 900

# %% [markdown]
# ## TensorMaps
# The critical data structure in the ML4CVD codebase is the TensorMap.
# This abstraction provides a way to translate ***any*** kind of input data, into structured numeric tensors with clear semantics for interpretation and modeling.

# %% [markdown]
# ## The Model Factory
# The function ***make_multimodal_multitask_model()*** takes lists of TensorMaps and connects them with intelligent goo.

# %% [markdown]
# ## Tensorization
# Is the process of gathering any number of input files and consolidating them into compressed HD5 files.  We tend to make one HD5 file per sample in the study.  The files contain the raw data and labels we will use to train models.  It tends to be efficient to separate tensor construction from model training.

# %%
# !mkdir ./dcm_scratch
# !rm -rf ./dcm_scratch/*
# !cp /home/sam/cq500/CQ500-CT-0.zip ./dcm_scratch/
# !unzip ./dcm_scratch/CQ500-CT-0.zip -d ./dcm_scratch/
# Out:
# mkdir: cannot create directory './dcm_scratch': File exists
# Archive:  ./dcm_scratch/CQ500-CT-0.zip
# Created by Orthanc
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000000.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000001.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000002.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000003.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000004.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000005.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000006.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000007.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000008.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000009.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000010.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000011.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000012.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000013.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000014.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000015.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000016.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000017.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000018.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000019.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000020.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000021.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000022.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000023.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000024.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000025.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000026.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000027.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000028.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000029.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000030.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000031.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000032.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000033.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000034.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000035.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000036.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000037.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000038.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000039.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000040.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000041.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000042.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000043.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000044.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000045.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000046.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000047.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000048.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000049.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000050.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000051.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000052.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000053.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000054.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000055.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000056.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000057.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000058.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000059.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000060.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000061.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000062.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000063.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000064.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000065.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000066.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000067.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000068.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000069.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000070.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000071.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000072.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000073.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000074.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000075.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000076.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000077.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000078.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000079.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000080.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000081.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000082.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000083.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000084.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000085.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000086.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000087.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000088.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000089.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000090.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000091.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000092.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000093.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000094.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000095.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000096.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000097.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000098.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000099.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000100.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000101.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000102.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000103.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000104.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000105.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000106.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000107.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000108.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000109.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000110.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000111.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000112.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000113.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000114.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000115.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000116.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000117.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000118.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000119.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000120.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000121.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000122.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000123.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000124.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000125.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000126.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000127.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000128.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000129.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000130.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000131.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000132.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000133.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000134.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000135.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000136.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000137.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000138.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000139.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000140.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000141.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000142.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000143.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000144.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000145.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000146.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000147.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000148.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000149.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000150.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000151.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000152.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000153.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000154.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000155.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000156.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000157.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000158.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000159.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000160.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000161.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000162.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000163.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000164.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000165.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000166.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000167.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000168.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000169.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000170.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000171.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000172.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000173.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000174.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000175.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000176.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000177.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000178.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000179.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000180.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000181.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000182.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000183.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000184.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000185.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000186.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000187.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000188.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000189.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000190.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000191.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000192.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000193.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000194.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000195.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000196.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000197.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000198.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000199.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000200.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000201.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000202.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000203.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000204.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000205.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000206.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000207.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000208.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000209.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000210.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000211.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000212.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000213.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000214.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000215.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000216.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000217.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000218.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000219.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000220.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000221.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000222.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000223.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000224.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000225.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000226.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000227.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000228.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000229.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000230.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000231.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000232.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000233.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000234.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000235.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000236.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000237.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on/CT000238.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000000.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000001.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000002.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000003.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000004.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000005.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000006.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000007.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000008.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000009.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000010.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000011.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000012.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000013.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000014.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000015.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000016.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000017.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000018.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000019.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000020.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000021.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000022.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000023.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000024.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000025.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000026.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000027.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000028.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000029.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000030.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000031.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000032.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000033.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000034.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000035.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000036.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000037.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000038.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000039.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000040.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000041.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000042.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000043.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000044.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000045.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000046.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000047.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000048.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000049.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000050.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000051.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000052.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000053.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000054.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000055.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000056.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000057.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000058.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000059.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000060.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000061.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000062.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000063.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000064.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000065.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000066.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000067.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000068.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000069.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000070.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000071.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000072.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000073.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000074.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000075.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000076.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000077.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000078.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000079.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000080.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000081.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000082.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000083.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000084.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000085.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000086.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000087.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000088.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000089.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000090.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000091.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000092.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000093.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000094.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000095.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000096.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000097.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000098.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000099.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000100.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000101.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000102.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000103.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000104.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000105.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000106.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000107.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000108.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000109.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000110.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000111.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000112.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000113.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000114.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000115.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000116.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000117.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000118.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000119.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000120.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000121.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000122.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000123.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000124.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000125.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000126.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000127.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000128.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000129.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000130.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000131.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000132.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000133.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000134.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000135.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000136.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000137.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000138.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000139.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000140.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000141.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000142.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000143.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000144.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000145.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000146.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000147.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000148.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000149.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000150.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000151.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000152.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000153.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000154.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000155.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000156.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000157.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000158.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000159.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000160.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000161.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000162.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000163.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000164.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000165.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000166.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000167.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000168.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000169.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000170.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000171.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000172.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000173.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000174.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000175.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000176.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000177.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000178.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000179.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000180.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000181.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000182.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000183.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000184.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000185.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000186.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000187.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000188.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000189.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000190.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000191.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000192.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000193.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000194.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000195.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000196.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000197.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000198.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000199.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000200.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000201.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000202.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000203.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000204.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000205.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000206.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000207.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000208.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000209.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000210.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000211.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000212.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000213.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000214.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000215.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000216.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000217.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000218.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000219.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000220.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000221.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000222.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000223.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000224.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000225.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000226.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000227.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000228.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000229.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000230.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000231.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000232.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000233.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000234.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000235.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000236.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000237.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-2/CT000238.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT Plain/CT000000.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT Plain/CT000001.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT Plain/CT000002.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT Plain/CT000003.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT Plain/CT000004.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT Plain/CT000005.dcm
# ...
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000059.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000060.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000061.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000062.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000063.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000064.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000065.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000066.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000067.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000068.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000069.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000070.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000071.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000072.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000073.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000074.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000075.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000076.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000077.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000078.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000079.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000080.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000081.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000082.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000083.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000084.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000085.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000086.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000087.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000088.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000089.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000090.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000091.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000092.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000093.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000094.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000095.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000096.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000097.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000098.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000099.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000100.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000101.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000102.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000103.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000104.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000105.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000106.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000107.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000108.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000109.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000110.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000111.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000112.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000113.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000114.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000115.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000116.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000117.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000118.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000119.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000120.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000121.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000122.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000123.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000124.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000125.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000126.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000127.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000128.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000129.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000130.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000131.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000132.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000133.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000134.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000135.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000136.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000137.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000138.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000139.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000140.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000141.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000142.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000143.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000144.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000145.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000146.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000147.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000148.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000149.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000150.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000151.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000152.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000153.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000154.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000155.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000156.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000157.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000158.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000159.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000160.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000161.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000162.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000163.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000164.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000165.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000166.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000167.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000168.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000169.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000170.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000171.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000172.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000173.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000174.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000175.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000176.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000177.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000178.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000179.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000180.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000181.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000182.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000183.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000184.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000185.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000186.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000187.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000188.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000189.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000190.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000191.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000192.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000193.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000194.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000195.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000196.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000197.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000198.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000199.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000200.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000201.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000202.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000203.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000204.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000205.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000206.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000207.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000208.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000209.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000210.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000211.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000212.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000213.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000214.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000215.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000216.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000217.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000218.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000219.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000220.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000221.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000222.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000223.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000224.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000225.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000226.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000227.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000228.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000229.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000230.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000231.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000232.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000233.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000234.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000235.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000236.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000237.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000238.dcm
#   inflating: ./dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT PLAIN THIN/CT000239.dcm

# %%
# !apt-get -y install python-gdcm
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libcharls1 libgdcm2.6 libjson-c2 libopenjpeg5 libsocket++1
# The following NEW packages will be installed:
#   libcharls1 libgdcm2.6 libjson-c2 libopenjpeg5 libsocket++1 python-gdcm
# 0 upgraded, 6 newly installed, 0 to remove and 104 not upgraded.
# Need to get 2611 kB of archives.
# After this operation, 15.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu xenial/main amd64 libjson-c2 amd64 0.11-4ubuntu2 [22.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu xenial/universe amd64 libcharls1 amd64 1.0-6 [50.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu xenial/universe amd64 libopenjpeg5 amd64 1:1.5.2-3.1 [104 kB]
# Get:4 http://archive.ubuntu.com/ubuntu xenial/universe amd64 libsocket++1 amd64 1.12.13-8wily1 [38.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu xenial/universe amd64 libgdcm2.6 amd64 2.6.3-3ubuntu3 [1801 kB]
# Get:6 http://archive.ubuntu.com/ubuntu xenial/universe amd64 python-gdcm amd64 2.6.3-3ubuntu3 [595 kB]
# Fetched 2611 kB in 1s (2153 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 6.)
# debconf: falling back to frontend: Readline
# Selecting previously unselected package libjson-c2:amd64.
# (Reading database ... 25059 files and directories currently installed.)
# Preparing to unpack .../libjson-c2_0.11-4ubuntu2_amd64.deb ...
# Unpacking libjson-c2:amd64 (0.11-4ubuntu2) ...
# Selecting previously unselected package libcharls1:amd64.
# Preparing to unpack .../libcharls1_1.0-6_amd64.deb ...
# Unpacking libcharls1:amd64 (1.0-6) ...
# Selecting previously unselected package libopenjpeg5:amd64.
# Preparing to unpack .../libopenjpeg5_1%3a1.5.2-3.1_amd64.deb ...
# Unpacking libopenjpeg5:amd64 (1:1.5.2-3.1) ...
# Selecting previously unselected package libsocket++1:amd64.
# Preparing to unpack .../libsocket++1_1.12.13-8wily1_amd64.deb ...
# Unpacking libsocket++1:amd64 (1.12.13-8wily1) ...
# Selecting previously unselected package libgdcm2.6:amd64.
# Preparing to unpack .../libgdcm2.6_2.6.3-3ubuntu3_amd64.deb ...
# Unpacking libgdcm2.6:amd64 (2.6.3-3ubuntu3) ...
# Selecting previously unselected package python-gdcm.
# Preparing to unpack .../python-gdcm_2.6.3-3ubuntu3_amd64.deb ...
# Unpacking python-gdcm (2.6.3-3ubuntu3) ...
# Processing triggers for libc-bin (2.23-0ubuntu10) ...
# Setting up libjson-c2:amd64 (0.11-4ubuntu2) ...
# Setting up libcharls1:amd64 (1.0-6) ...
# Setting up libopenjpeg5:amd64 (1:1.5.2-3.1) ...
# Setting up libsocket++1:amd64 (1.12.13-8wily1) ...
# Setting up libgdcm2.6:amd64 (2.6.3-3ubuntu3) ...
# Setting up python-gdcm (2.6.3-3ubuntu3) ...
# Processing triggers for libc-bin (2.23-0ubuntu10) ...

# %%
import pydicom
import gdcm
stats = Counter()
dcm_dir = './dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-3/'
for dcm_file in os.listdir(dcm_dir):
    if not dcm_file.endswith('.dcm'):
        continue
    dcm = pydicom.read_file(dcm_dir + dcm_file)
    stats['count'] += 1
    stats[f'series_num_{dcm.SeriesNumber}'] += 1
    stats[f'instance_num_{dcm.SeriesDescription}'] += 1
    stats[f'Pixel spacing{dcm.PixelSpacing}'] += 1
    stats[f'Shape {dcm.pixel_array.shape}'] += 1
    print(dcm)
    break
for k in stats:
    print(f'{k} has {stats[k]}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-ca5ca4ed49fc> in <module>
#       1 import pydicom
# ----> 2 import gdcm
#       3 stats = Counter()
#       4 dcm_dir = './dcm_scratch/CQ500CT0 CQ500CT0/Unknown Study/CT 4cc sec 150cc D3D on-3/'
#       5 for dcm_file in os.listdir(dcm_dir):
#
# ModuleNotFoundError: No module named 'gdcm'

# %%
def tmaps_by_sample_id(tensor_folder: str, sample_id: str, tmaps: List[TensorMap]):
    path = os.path.join(tensor_folder, sample_id + '.hd5')
    result_dict = defaultdict(lambda: None)
    if os.path.isfile(path):
            with h5py.File(path, 'r') as hd5:
                for tmap in tmaps:
                    try:
                        result_dict[tmap] = tmap.tensor_from_file(tmap, hd5)
                    except (IndexError, KeyError, ValueError, OSError, RuntimeError):
                        continue
    return result_dict


def tmaps_with_properties(tensor_folder: str, tmap_properties: Dict[TensorMap, Callable[[np.ndarray], bool]], search_size=100):
    all_ids = [file.strip('.hd5') for file in sorted(os.listdir(tensor_folder))[:search_size]]
    results = map(lambda sample_id: tmaps_by_sample_id(tensor_folder, sample_id, tmap_properties.keys()), all_ids)
    return {
        sample_id: result
        for sample_id, result in zip(all_ids, results)
        if all(
            result[tmap] is not None and tmap_properties[tmap](result[tmap])
            for tmap in tmap_properties.keys()
        )
    }


def tmaps_with_properties_from_keys(tensor_folder: str, tmap_properties: Dict[str, Callable[[np.ndarray], bool]], search_size=100):
    return tmaps_with_properties(
        tensor_folder,
        {_get_tmap(key): prop for key, prop in tmap_properties.items()},
        search_size,
    )


def plot_array_3d(a):
    slice_axis = -1
    sides = int(np.ceil(np.sqrt(a.shape[slice_axis])))
    _, axes = plt.subplots(sides, sides, figsize=(16, 16))
    print(a.shape)
    vmin = np.min(a)
    vmax = np.max(a)
    for i in range(a.shape[slice_axis]):
        axes[i//sides, i%sides].imshow(a[..., i], cmap='gray', vmin=vmin, vmax=vmax)
        axes[i//sides, i%sides].set_yticklabels([])
        axes[i//sides, i%sides].set_xticklabels([])

# %%
tmaps = [_get_tmap('t1_30_slices'), _get_tmap('t1_dicom_30_slices'),_get_tmap('t2_flair_30_slices'), _get_tmap('t2_dicom_30_slices')]

# %%
t = tmaps_by_sample_id('/mnt/disks/brain-tensors-all-40k/2020-01-14/', '3035859', tmaps)
for k in t:
    print(k.name, 'has', t[k].shape)

# %%
for k in t:
    plot_array_3d(t[k])

# %% [markdown]
# The Erowid Data Scrape.

# %%
http://human.brain-map.org/mri_viewers/data
